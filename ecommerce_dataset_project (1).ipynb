# %%
# !hdfs dfs -ls /data/project/
# Out:
# Found 3 items
# drwxr-xr-x   - pc   hadoop          0 2025-11-11 16:28 /data/project/archive
# drwxr-xr-x   - root hadoop          0 2025-11-11 16:34 /data/project/cleaned_order_details.parquet
# -rw-r--r--   2 pc   hadoop  284122744 2025-11-11 16:26 /data/project/orders.csv

# %% [markdown]
# **Setting up spark environment**

# %%
from pyspark.sql import SparkSession

spark=SparkSession.builder\
.appName("Olist data")\
.master("yarn")\
.getOrCreate()
# Out:
# 25/11/14 09:28:48 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %% [markdown]
# **reading data files into respective spark data frames**

# %%
hdfs_path='/data/project/archive/'

# %%
customer_df=spark.read.format("csv")\
.option("header","true")\
.option("inferSchema","true")\
.load(hdfs_path+'olist_customers_dataset.csv')

# %%
customer_df.printSchema()
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_unique_id: string (nullable = true)
#  |-- customer_zip_code_prefix: integer (nullable = true)
#  |-- customer_city: string (nullable = true)
#  |-- customer_state: string (nullable = true)

# %%
customer_df.show()
# Out:
# +--------------------+--------------------+------------------------+--------------------+--------------+
# |         customer_id|  customer_unique_id|customer_zip_code_prefix|       customer_city|customer_state|
# +--------------------+--------------------+------------------------+--------------------+--------------+
# |06b8999e2fba1a1fb...|861eff4711a542e4b...|                   14409|              franca|            SP|
# |18955e83d337fd6b2...|290c77bc529b7ac93...|                    9790|sao bernardo do c...|            SP|
# |4e7b3e00288586ebd...|060e732b5b29e8181...|                    1151|           sao paulo|            SP|
# |b2b6027bc5c5109e5...|259dac757896d24d7...|                    8775|     mogi das cruzes|            SP|
# |4f2d8ab171c80ec83...|345ecd01c38d18a90...|                   13056|            campinas|            SP|
# |879864dab9bc30475...|4c93744516667ad3b...|                   89254|      jaragua do sul|            SC|
# |fd826e7cf63160e53...|addec96d2e059c80c...|                    4534|           sao paulo|            SP|
# |5e274e7a0c3809e14...|57b2a98a409812fe9...|                   35182|             timoteo|            MG|
# |5adf08e34b2e99398...|1175e95fb47ddff9d...|                   81560|            curitiba|            PR|
# |4b7139f34592b3a31...|9afe194fb833f79e3...|                   30575|      belo horizonte|            MG|
# |9fb35e4ed6f0a14a4...|2a7745e1ed516b289...|                   39400|       montes claros|            MG|
# |5aa9e4fdd4dfd2095...|2a46fb94aef5cbeeb...|                   20231|      rio de janeiro|            RJ|
# |b2d1536598b73a9ab...|918dc87cd72cd9f6e...|                   18682|    lencois paulista|            SP|
# |eabebad39a88bb6f5...|295c05e81917928d7...|                    5704|           sao paulo|            SP|
# |1f1c7bf1c9b041b29...|3151a81801c838636...|                   95110|       caxias do sul|            RS|
# |206f3129c0e4d7d0b...|21f748a16f4e1688a...|                   13412|          piracicaba|            SP|
# |a7c125a0a07b75146...|5c2991dbd08bbf3cf...|                   22750|      rio de janeiro|            RJ|
# |c5c61596a3b6bd0ce...|b6e99561fe6f34a55...|                    7124|           guarulhos|            SP|
# |9b8ce803689b3562d...|7f3a72e8f988c6e73...|                    5416|           sao paulo|            SP|
# |49d0ea0986edde72d...|3e6fd6b2f0d499456...|                   68485|              pacaja|            PA|
# +--------------------+--------------------+------------------------+--------------------+--------------+
# only showing top 20 rows

# %%
geolocation_df=spark.read.format("csv")\
.option("header","true")\
.option("inferSchema","true")\
.load(hdfs_path+"olist_geolocation_dataset.csv")

geolocation_df.printSchema()
geolocation_df.show()
# Out:
# root
#  |-- geolocation_zip_code_prefix: integer (nullable = true)
#  |-- geolocation_lat: double (nullable = true)
#  |-- geolocation_lng: double (nullable = true)
#  |-- geolocation_city: string (nullable = true)
#  |-- geolocation_state: string (nullable = true)
#
# +---------------------------+-------------------+-------------------+----------------+-----------------+
# |geolocation_zip_code_prefix|    geolocation_lat|    geolocation_lng|geolocation_city|geolocation_state|
# +---------------------------+-------------------+-------------------+----------------+-----------------+
#
# |00063b381e2406b52...|            1|f177554ea93259a5b...|8602a61d680a10a82...|2018-07-31 17:30:39|  45.0|        12.98|
# |0006ec9db01a64e59...|            1|99a4788cb24856965...|4a3ca9315b744ce9f...|2018-07-26 17:24:20|  74.0|        23.32|
# |0008288aa423d2a3f...|            1|368c6c730842d7801...|1f50f920176fa81da...|2018-02-21 02:55:52|  49.9|        13.37|
# |0008288aa423d2a3f...|            2|368c6c730842d7801...|1f50f920176fa81da...|2018-02-21 02:55:52|  49.9|        13.37|
# |0009792311464db53...|            1|8cab8abac59158715...|530ec6109d11eaaf8...|2018-08-17 12:15:10|  99.9|        27.65|
# |0009c9a17f916a706...|            1|3f27ac8e699df3d30...|fcb5ace8bcc92f757...|2018-05-02 09:31:53| 639.0|        11.34|
# |000aed2e25dbad2f9...|            1|4fa33915031a8cde0...|fe2032dab1a61af87...|2018-05-16 20:57:03| 144.0|         8.77|
# |000c3e6612759851c...|            1|b50c950aba0dcead2...|218d46b86c1881d02...|2017-08-21 03:33:13|  99.0|        13.71|
# |000e562887b1f2006...|            1|5ed9eaf534f6936b5...|8cbac7e12637ed9cf...|2018-02-28 12:08:37|  25.0|        16.11|
# +--------------------+-------------+--------------------+--------------------+-------------------+------+-------------+
# only showing top 20 rows

# %%
order_payments_df=spark.read.format("csv")\
.option("header","true")\
.option("inferSchema","true")\
.load(hdfs_path+"olist_order_payments_dataset.csv")

order_payments_df.printSchema()
order_payments_df.show()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- payment_sequential: integer (nullable = true)
#  |-- payment_type: string (nullable = true)
#  |-- payment_installments: integer (nullable = true)
#  |-- payment_value: double (nullable = true)
#
# +--------------------+------------------+------------+--------------------+-------------+
# |            order_id|payment_sequential|payment_type|payment_installments|payment_value|
# +--------------------+------------------+------------+--------------------+-------------+
# |b81ef226f3fe1789b...|                 1| credit_card|                   8|        99.33|
# |a9810da82917af2d9...|                 1| credit_card|                   1|        24.39|
# |25e8ea4e93396b6fa...|                 1| credit_card|                   1|        65.71|
# |ba78997921bbcdc13...|                 1| credit_card|                   8|       107.78|
# |42fdf880ba16b47b5...|                 1| credit_card|                   2|       128.45|
# |298fcdf1f73eb413e...|                 1| credit_card|                   2|        96.12|
# |771ee386b001f0620...|                 1| credit_card|                   1|        81.16|
# |3d7239c394a212faa...|                 1| credit_card|                   3|        51.84|
# |1f78449c87a54faf9...|                 1| credit_card|                   6|       341.09|
# |0573b5e23cbd79800...|                 1|      boleto|                   1|        51.95|
# |d88e0d5fa41661ce0...|                 1| credit_card|                   8|       188.73|
# |2480f727e869fdeb3...|                 1| credit_card|                   1|        141.9|
# |616105c9352a9668c...|                 1| credit_card|                   1|        75.78|
# |cf95215a722f3ebf2...|                 1| credit_card|                   5|       102.66|
# |769214176682788a9...|                 1| credit_card|                   4|       105.28|
# |12e5cfe0e4716b59a...|                 1| credit_card|                  10|       157.45|
# |61059985a6fc0ad64...|                 1| credit_card|                   1|       132.04|
# |79da3f5fe31ad1e45...|                 1| credit_card|                   1|        98.94|
# |8ac09207f415d55ac...|                 1| credit_card|                   4|       244.15|
# |b2349a3f20dfbeef6...|                 1| credit_card|                   3|       136.71|
# +--------------------+------------------+------------+--------------------+-------------+
# only showing top 20 rows

# %%
order_reviews_df=spark.read.format("csv")\
.option("header","true")\
.option("inferSchema","true")\
.load(hdfs_path+"olist_order_reviews_dataset.csv")

order_reviews_df.printSchema()
order_reviews_df.show()
# Out:
# root
#  |-- review_id: string (nullable = true)
#  |-- order_id: string (nullable = true)
#  |-- review_score: string (nullable = true)
#  |-- review_comment_title: string (nullable = true)
#  |-- review_comment_message: string (nullable = true)
#  |-- review_creation_date: string (nullable = true)
#  |-- review_answer_timestamp: string (nullable = true)
#
# +--------------------+--------------------+------------+--------------------+----------------------+--------------------+-----------------------+
# |           review_id|            order_id|review_score|review_comment_title|review_comment_message|review_creation_date|review_answer_timestamp|
# +--------------------+--------------------+------------+--------------------+----------------------+--------------------+-----------------------+
# |7bc2406110b926393...|73fc7af87114b3971...|           4|                NULL|                  NULL| 2018-01-18 00:00:00|    2018-01-18 21:46:59|
# |80e641a11e56f04c1...|a548910a1c6147796...|           5|                NULL|                  NULL| 2018-03-10 00:00:00|    2018-03-11 03:05:13|
# |228ce5500dc1d8e02...|f9e4b658b201a9f2e...|           5|                NULL|                  NULL| 2018-02-17 00:00:00|    2018-02-18 14:36:24|

# +--------------------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+
# only showing top 20 rows

# %%
sellers_df=spark.read.format("csv")\
.option("header","true")\
.option("inferSchema","true")\
.load(hdfs_path+"olist_sellers_dataset.csv")

sellers_df.printSchema()
sellers_df.show()
# Out:
# root
#  |-- seller_id: string (nullable = true)
#  |-- seller_zip_code_prefix: integer (nullable = true)
#  |-- seller_city: string (nullable = true)
#  |-- seller_state: string (nullable = true)
#
# +--------------------+----------------------+-----------------+------------+
# |           seller_id|seller_zip_code_prefix|      seller_city|seller_state|
# +--------------------+----------------------+-----------------+------------+
# |3442f8959a84dea7e...|                 13023|         campinas|          SP|
# |d1b65fc7debc3361e...|                 13844|       mogi guacu|          SP|
# |ce3ad9de960102d06...|                 20031|   rio de janeiro|          RJ|
# |c0f3eea2e14555b6f...|                  4195|        sao paulo|          SP|
# |51a04a8a6bdcb23de...|                 12914|braganca paulista|          SP|
# |c240c4061717ac180...|                 20920|   rio de janeiro|          RJ|
# |e49c26c3edfa46d22...|                 55325|           brejao|          PE|
# |1b938a7ec6ac5061a...|                 16304|        penapolis|          SP|
# |768a86e36ad6aae3d...|                  1529|        sao paulo|          SP|
# |ccc4bbb5f32a6ab2b...|                 80310|         curitiba|          PR|
# |8cb7c5ddf41f4d506...|                 75110|         anapolis|          GO|
# |a7a9b880c49781da6...|                 13530|        itirapina|          SP|
# |8bd0f31cf0a614c65...|                  1222|        sao paulo|          SP|
# |05a48cc8859962767...|                  5372|        sao paulo|          SP|
# |7b8e8ec35bad4b0ef...|                 88705|          tubarao|          SC|
# |1444c08e64d55fb3c...|                 42738| lauro de freitas|          BA|
# |166e8f1381e096519...|                 88780|         imbituba|          SC|
# |e38db885400cd35c7...|                 70740|         brasilia|          DF|
# |d2e753bb80b7d4faa...|                 45810|     porto seguro|          BA|
# |f9ec7093df3a7b346...|                  5138|        sao paulo|          SP|
# +--------------------+----------------------+-----------------+------------+
# only showing top 20 rows

# %%
product_translation_df=spark.read.format("csv")\
.option("header","true")\
.option("inferSchema","true")\
.load(hdfs_path+"product_category_name_translation.csv")

product_translation_df.printSchema()
product_translation_df.show()
# Out:
# root
#  |-- product_category_name: string (nullable = true)
#  |-- product_category_name_english: string (nullable = true)
#
# +---------------------+-----------------------------+
# |product_category_name|product_category_name_english|
# +---------------------+-----------------------------+
# |         beleza_saude|                health_beauty|
# | informatica_acess...|         computers_accesso...|
# |           automotivo|                         auto|
# |      cama_mesa_banho|               bed_bath_table|
# |     moveis_decoracao|              furniture_decor|
# |        esporte_lazer|               sports_leisure|
# |           perfumaria|                    perfumery|
# | utilidades_domest...|                   housewares|
# |            telefonia|                    telephony|
# |   relogios_presentes|                watches_gifts|
# |    alimentos_bebidas|                   food_drink|
# |                bebes|                         baby|
# |            papelaria|                   stationery|
# | tablets_impressao...|         tablets_printing_...|
# |           brinquedos|                         toys|
# |       telefonia_fixa|              fixed_telephony|
# |   ferramentas_jardim|                 garden_tools|
# | fashion_bolsas_e_...|         fashion_bags_acce...|
# |      eletroportateis|             small_appliances|
# |       consoles_games|               consoles_games|
# +---------------------+-----------------------------+
# only showing top 20 rows

# %%
# %whos DataFrame
# Out:
# Variable                 Type         Data/Info
# -----------------------------------------------
# customer_df              DataFrame    DataFrame[customer_id: st<...>, customer_state: string]
# geolocation_df           DataFrame    DataFrame[geolocation_zip<...>eolocation_state: string]
# order_items_df           DataFrame    DataFrame[order_id: strin<...>e, freight_value: double]
# order_payments_df        DataFrame    DataFrame[order_id: strin<...>t, payment_value: double]
# order_reviews_df         DataFrame    DataFrame[review_id: stri<...>answer_timestamp: string]
# orders_df                DataFrame    DataFrame[order_id: strin<...>delivery_date: timestamp]
# product_translation_df   DataFrame    DataFrame[product_categor<...>ory_name_english: string]
# products_df              DataFrame    DataFrame[product_id: str<...>t, product_width_cm: int]
# sellers_df               DataFrame    DataFrame[seller_id: stri<...>ng, seller_state: string]

# %% [markdown]
# **validating correct data loading**

# %%
print(f"customer_df rows: {customer_df.count()}\
\ngeolocation_df rows: {geolocation_df.count()}\
\norder_items_df rows: {order_items_df.count()}\
\norder_payments_df rows: {order_payments_df.count()}\
\norder_reviews_df rows: {order_reviews_df.count()}\
\norders_df rows: {orders_df.count()}\
\nproduct_translation_df rows: {product_translation_df.count()}\
\nproducts_df rows: {products_df.count()}\
\nsellers_df rows: {sellers_df.count()}")
# Out:
# customer_df rows: 99441
# geolocation_df rows: 1000163
# order_items_df rows: 112650
# order_payments_df rows: 103886
# order_reviews_df rows: 104162
# orders_df rows: 99441
# product_translation_df rows: 71
# products_df rows: 32951
# sellers_df rows: 3095

# %% [markdown]
# **NULL/DUPLICATE values check**

# %%
from pyspark.sql.functions import *

def check_missing_values(df,df_name):
    print(f"missing values in {df_name} dataframe\n")
    df.select([sum(when(col(c).isNull(),1).otherwise(0)).alias(c) for c in df.columns]).show()

# %%
check_missing_values(customer_df,"customers")
check_missing_values(geolocation_df,"geolocation")
check_missing_values(order_items_df,"order items")
check_missing_values(order_payments_df,"order payments")
check_missing_values(order_reviews_df,"order reviews")
check_missing_values(orders_df,"orders")
check_missing_values(sellers_df,"sellers")
check_missing_values(products_df,"products")
check_missing_values(product_translation_df,"product translation")
# Out:
# missing values in customers dataframe
#
# +-----------+------------------+------------------------+-------------+--------------+
# |customer_id|customer_unique_id|customer_zip_code_prefix|customer_city|customer_state|
# +-----------+------------------+------------------------+-------------+--------------+
# |          0|                 0|                       0|            0|             0|
# +-----------+------------------+------------------------+-------------+--------------+
#
# missing values in geolocation dataframe
# +---------------------------+---------------+---------------+----------------+-----------------+
# |geolocation_zip_code_prefix|geolocation_lat|geolocation_lng|geolocation_city|geolocation_state|
# +---------------------------+---------------+---------------+----------------+-----------------+
# |                          0|              0|              0|               0|                0|
# +---------------------------+---------------+---------------+----------------+-----------------+
#
# missing values in order items dataframe
#
# +--------+-------------+----------+---------+-------------------+-----+-------------+
# |order_id|order_item_id|product_id|seller_id|shipping_limit_date|price|freight_value|
# +--------+-------------+----------+---------+-------------------+-----+-------------+
# |       0|            0|         0|        0|                  0|    0|            0|
# +--------+-------------+----------+---------+-------------------+-----+-------------+
#
# missing values in order payments dataframe
#
# +--------+------------------+------------+--------------------+-------------+
# |order_id|payment_sequential|payment_type|payment_installments|payment_value|
# +--------+------------------+------------+--------------------+-------------+
# |       0|                 0|           0|                   0|            0|
# +--------+------------------+------------+--------------------+-------------+
#
# missing values in order reviews dataframe
#
# +---------+--------+------------+--------------------+----------------------+--------------------+-----------------------+
# |review_id|order_id|review_score|review_comment_title|review_comment_message|review_creation_date|review_answer_timestamp|
# +---------+--------+------------+--------------------+----------------------+--------------------+-----------------------+
# |        1|    2236|        2380|               92157|                 63079|                8764|                   8785|
# +---------+--------+------------+--------------------+----------------------+--------------------+-----------------------+
#
# missing values in orders dataframe
#
# +--------+-----------+------------+------------------------+-----------------+----------------------------+-----------------------------+-----------------------------+
# |order_id|customer_id|order_status|order_purchase_timestamp|order_approved_at|order_delivered_carrier_date|order_delivered_customer_date|order_estimated_delivery_date|
# +--------+-----------+------------+------------------------+-----------------+----------------------------+-----------------------------+-----------------------------+
# |       0|          0|           0|                       0|              160|                        1783|                         2965|                            0|
# +--------+-----------+------------+------------------------+-----------------+----------------------------+-----------------------------+-----------------------------+
#
# missing values in sellers dataframe
#
# +---------+----------------------+-----------+------------+
# |seller_id|seller_zip_code_prefix|seller_city|seller_state|
# +---------+----------------------+-----------+------------+
# |        0|                     0|          0|           0|
# +---------+----------------------+-----------+------------+
#
# missing values in products dataframe
#
# +----------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+
# |product_id|product_category_name|product_name_lenght|product_description_lenght|product_photos_qty|product_weight_g|product_length_cm|product_height_cm|product_width_cm|
# +----------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+
# |         0|                  610|                610|                       610|               610|               2|                2|                2|               2|
# +----------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+
#
# missing values in product translation dataframe
#
# +---------------------+-----------------------------+
# |product_category_name|product_category_name_english|
# +---------------------+-----------------------------+
# |                    0|                            0|
# +---------------------+-----------------------------+

# %% [markdown]
# **so products\_df, orders\_df, order\_reviews\_df have null values in their cols**

# %%
#handle missing values
order_reviews_df=order_reviews_df.fillna({'review_id':99999}) 
order_reviews_df=order_reviews_df.dropna(subset=['order_id'])

# %%
check_missing_values(order_reviews_df,"order reviews")
# Out:
# missing values in order reviews dataframe
#
# +---------+--------+------------+--------------------+----------------------+--------------------+-----------------------+
# |review_id|order_id|review_score|review_comment_title|review_comment_message|review_creation_date|review_answer_timestamp|
# +---------+--------+------------+--------------------+----------------------+--------------------+-----------------------+
# |        0|       0|         144|               89922|                 60843|                6528|                   6549|
# +---------+--------+------------+--------------------+----------------------+--------------------+-----------------------+

# %% [markdown]
# **now lets check for duplicates**

# %%
def check_duplicates(df,key,df_name):
    print(f"duplicates in {df_name} dataframe\n")
    df.groupBy(key).count().filter(col('count')>1).show()

# %%
check_duplicates(products_df,['product_id'],'products')
check_duplicates(order_items_df,['order_id','product_id','seller_id'],'order items')
check_duplicates(customer_df,['customer_id'],'customers')
check_duplicates(orders_df,['order_id'],'orders')
check_duplicates(order_payments_df,['order_id'],'order_payments')
check_duplicates(order_reviews_df,['order_id','review_id'],'order_reviews')
check_duplicates(geolocation_df,['geolocation_zip_code_prefix'],'geolocation')
check_duplicates(sellers_df,['seller_id'],'sellers')
# Out:
# duplicates in products dataframe
# +----------+-----+
# |product_id|count|
# +----------+-----+
# +----------+-----+
#
# duplicates in order items dataframe
# +--------------------+--------------------+--------------------+-----+
# |            order_id|          product_id|           seller_id|count|
# +--------------------+--------------------+--------------------+-----+
# |2059a6cad3cfd50e2...|e48406fb377b0bf86...|9803a40e82e45418a...|    2|
# |73cbd9a357e885c90...|a5f25345083fc9e53...|83b08de9698075722...|    3|
# |96519c210f6dfe22f...|027cdd14a677a5834...|81f89e42267213cb9...|    2|
# |095234196e1f3c4fe...|368c6c730842d7801...|1f50f920176fa81da...|    3|
# |16febac56c216c1cc...|64ea282a67530101b...|4a3ca9315b744ce9f...|    4|
# |2fb7dfe5fec51c8a9...|389d119b48cf3043d...|1f50f920176fa81da...|    2|
# |66b9c991ee308f934...|19936fa4f614ee059...|b37c4c02bda3161a7...|    2|
# |9883744c6400cfad8...|595fac2a385ac33a8...|ef0ace09169ac0905...|    2|
# |2dd1b3fcb05d15852...|3609dcfca328f686e...|516e7738bd8f735ac...|    2|
# |3fef122997c747784...|8b45810da2ef98604...|1900267e848ceeba8...|    2|
# |468c8b5d4cee2be21...|584d0486add75aa0f...|e9d99831abad74458...|    6|
# |35ebb30703c580bff...|520aadbf40e95a61e...|5a8e7d5003a1f221f...|    2|
# |5ac65ba68cda958df...|02a1edfc6f788c832...|0be8ff43f22e456b4...|    2|
# |78ee9d46bf8b130d3...|42a2c92a0979a949c...|813348c996469b40f...|    2|
# |8dd925f0031d0e5f4...|481587fdec29c4d63...|830379336fad8c6f3...|    2|
# |0ff2ccfa60758f365...|cec6ba506483e1764...|1f50f920176fa81da...|    3|
# |1eba8812bd34c3579...|53759a2ecddad2bb8...|1f50f920176fa81da...|    2|
# |2779755b606fbe6d1...|acde6bd0b5f91190e...|36a968b544695394e...|    2|
# |80d817467dc3d0a4b...|425db55cb3b0f5b18...|2a84855fd20af891b...|    2|
# |12f3eaf92da599fd1...|45852eb1811c96c22...|da8622b14eb17ae28...|    2|
# +--------------------+--------------------+--------------------+-----+
# only showing top 20 rows
#
# duplicates in customers dataframe
#
# +-----------+-----+
# |customer_id|count|
# +-----------+-----+
# +-----------+-----+
#
# duplicates in orders dataframe
#
# +--------+-----+
# |order_id|count|
# +--------+-----+
# +--------+-----+
#
# duplicates in order_payments dataframe
#
# +--------------------+-----+
# |            order_id|count|
# +--------------------+-----+
# |8ca5bdac5ebe8f2d6...|    9|
# |54066aeaaf3ac32e7...|    2|
# |f44cb69655f8e4d13...|    2|
# |cd05a1fc2781f43f5...|    2|
# |7a5472f7c8cecc2e1...|    2|
# |35ab20ce8b706d545...|    2|
# |3f4f6a378519479cb...|    2|
# |251f0a3981c4a8cb8...|    5|
# |1826d2a2eb6ba6e3e...|    2|
# |8dd9758206f8d9c23...|    2|
# |b1ce906877fd32ecc...|    2|
# |eb73628992e7d5099...|    2|
# |818877ced1be365d1...|    2|
# |6064862631581009b...|    4|
# |7f344d881ecc07068...|    2|
# |f6ba6de181266b918...|    2|
# |d8d126f05b944cb1a...|    2|
# |0fc3e31f16aa4bc4b...|    2|
# |37a7476e58da10721...|    2|
# |f1d6313ed30c82ba1...|    4|
# +--------------------+-----+
# only showing top 20 rows
#
# duplicates in order_reviews dataframe
# +--------------------+--------------------+-----+
# |            order_id|           review_id|count|
# +--------------------+--------------------+-----+
# |infelizmente não ...|Era pra dar de pr...|    2|
# | 2017-09-14 00:00:00|Fizemos uma notif...|    2|
# | 2018-03-20 00:00:00|eu super recomend...|    2|
# | atrás dela é tip...|Também a ponta da...|    2|
# | 2016-10-27 00:00:00|           Obrigada"|    2|
# | 2018-02-24 00:00:00|Não recebi o prod...|    2|
# | 2018-05-23 00:00:00|                   "|    2|
# | 2017-09-15 00:00:00|          Obrigada "|    2|
# | 2017-11-22 00:00:00|A única coisa que...|    2|
# | 2018-03-16 00:00:00|muito feliz pelo ...|    2|
# | 2018-03-21 00:00:00|A resolução das i...|    2|
# | 2018-08-18 00:00:00|quero meu dinheir...|    3|
# | 2017-08-24 00:00:00|O amarelo não rec...|    2|
# | 2018-08-02 00:00:00|Foram entregues l...|    2|
# | 2018-03-03 00:00:00|Qto ao produto ai...|    2|
# | 2016-10-29 00:00:00| Vendedor nota 1000"|    2|
# | 2018-08-15 00:00:00|MANDAMOS E-MAIL F...|    2|
# | 2018-03-07 00:00:00|TEM COMO VCS VERI...|    2|
# | 2017-08-02 00:00:00|Aguardo um retorno."|    2|
# | mas ninguém entr...|Recebi o aviso de...|    2|
# +--------------------+--------------------+-----+
# only showing top 20 rows
#
# duplicates in geolocation dataframe
# +---------------------------+-----+
# |geolocation_zip_code_prefix|count|
# +---------------------------+-----+
# |                       2122|   33|
# |                       2366|   33|
# |                       3918|   50|
# |                       4101|   72|
# |                       9852|  107|
# |                      13289|   61|
# |                      26087|  111|
# |                      28024|   95|
# |                       3226|   24|
# |                       4190|   52|
# |                      18201|   69|
# |                      20396|   11|
# |                       1303|  166|
# |                       6825|   22|
# |                       8257|   60|
# |                      13483|   83|
# |                      24855|   41|
# |                      25638|    2|
# |                       2443|   80|
# |                       2721|  149|
# +---------------------------+-----+
# only showing top 20 rows
#
# duplicates in sellers dataframe
#
# +---------+-----+
# |seller_id|count|
# +---------+-----+
# +---------+-----+

# %% [markdown]
# **customer dist by state**

# %%
customer_df.groupBy('customer_state').count().orderBy(col('count').desc()).show()
# Out:
# +--------------+-----+
# |customer_state|count|
# +--------------+-----+
# |            SP|41746|
# |            RJ|12852|
# |            MG|11635|
# |            RS| 5466|
# |            PR| 5045|
# |            SC| 3637|
# |            BA| 3380|
# |            DF| 2140|
# |            ES| 2033|
# |            GO| 2020|
# |            PE| 1652|
# |            CE| 1336|
# |            PA|  975|
# |            MT|  907|
# |            MA|  747|
# |            MS|  715|
# |            PB|  536|
# |            PI|  495|
# |            RN|  485|
# |            AL|  413|
# +--------------+-----+
# only showing top 20 rows

# %% [markdown]
# **order status dist**

# %%
orders_df.groupBy('order_status').count().orderBy(col('count').desc()).show()
# Out:
# +------------+-----+
# |order_status|count|
# +------------+-----+
# |   delivered|96478|
# |     shipped| 1107|
# |    canceled|  625|
# | unavailable|  609|
# |    invoiced|  314|
# |  processing|  301|
# |     created|    5|
# |    approved|    2|
# +------------+-----+

# %% [markdown]
# **payments**

# %%
order_payments_df.show()
# Out:
# +--------------------+------------------+------------+--------------------+-------------+
# |            order_id|payment_sequential|payment_type|payment_installments|payment_value|
# +--------------------+------------------+------------+--------------------+-------------+
# |b81ef226f3fe1789b...|                 1| credit_card|                   8|        99.33|
# |a9810da82917af2d9...|                 1| credit_card|                   1|        24.39|
# |25e8ea4e93396b6fa...|                 1| credit_card|                   1|        65.71|
# |ba78997921bbcdc13...|                 1| credit_card|                   8|       107.78|
# |42fdf880ba16b47b5...|                 1| credit_card|                   2|       128.45|
# |298fcdf1f73eb413e...|                 1| credit_card|                   2|        96.12|
# |771ee386b001f0620...|                 1| credit_card|                   1|        81.16|
# |3d7239c394a212faa...|                 1| credit_card|                   3|        51.84|
# |1f78449c87a54faf9...|                 1| credit_card|                   6|       341.09|
# |0573b5e23cbd79800...|                 1|      boleto|                   1|        51.95|
# |d88e0d5fa41661ce0...|                 1| credit_card|                   8|       188.73|
# |2480f727e869fdeb3...|                 1| credit_card|                   1|        141.9|
# |616105c9352a9668c...|                 1| credit_card|                   1|        75.78|
# |cf95215a722f3ebf2...|                 1| credit_card|                   5|       102.66|
# |769214176682788a9...|                 1| credit_card|                   4|       105.28|
# |12e5cfe0e4716b59a...|                 1| credit_card|                  10|       157.45|
# |61059985a6fc0ad64...|                 1| credit_card|                   1|       132.04|
# |79da3f5fe31ad1e45...|                 1| credit_card|                   1|        98.94|
# |8ac09207f415d55ac...|                 1| credit_card|                   4|       244.15|
# |b2349a3f20dfbeef6...|                 1| credit_card|                   3|       136.71|
# +--------------------+------------------+------------+--------------------+-------------+
# only showing top 20 rows

# %%
order_payments_df.groupBy('payment_type').count().orderBy(col('count').desc()).show()
# Out:
# +------------+-----+
# |payment_type|count|
# +------------+-----+
# | credit_card|76795|
# |      boleto|19784|
# |     voucher| 5775|
# |  debit_card| 1529|
# | not_defined|    3|
# +------------+-----+

# %% [markdown]
# **order items**

# %%
top_products=order_items_df.groupBy('product_id').agg(sum('price').alias('total_sales')).orderBy(col('total_sales').desc())
top_products.show()
# Out:
# +--------------------+------------------+
# |          product_id|       total_sales|
# +--------------------+------------------+
# |bb50f2e236e5eea01...|           63885.0|
# |6cdd53843498f9289...| 54730.20000000005|
# |d6160fb7873f18409...|48899.340000000004|
# |d1c427060a0f73f6b...| 47214.51000000006|
# |99a4788cb24856965...|43025.560000000085|
# |3dd2a17168ec895c7...| 41082.60000000005|
# |25c38557cf793876c...| 38907.32000000001|
# |5f504b3a1c75b73d6...|37733.899999999994|
# |53b36df67ebb7c415...| 37683.42000000001|
# |aca2eb7d00ea1a7b8...| 37608.90000000007|
# |e0d64dcfaa3b6db5c...|          31786.82|
# |d285360f29ac7fd97...|31623.809999999983|
# |7a10781637204d8d1...|           30467.5|
# |f1c7f353075ce59d8...|          29997.36|
# |f819f0c84a64f02d3...|29024.479999999996|
# |588531f8ec37e7d5f...|28291.989999999998|
# |422879e10f4668299...|26577.219999999972|
# |16c4e87b98a9370a9...|           25034.0|
# |5a848e4ab52fd5445...|24229.029999999962|
# |a62e25e09e05e6faf...|           24051.0|
# +--------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# **avg delivery time analysis**

# %%
orders_df.show()
# Out:
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# |            order_id|         customer_id|order_status|order_purchase_timestamp|  order_approved_at|order_delivered_carrier_date|order_delivered_customer_date|order_estimated_delivery_date|
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# |e481f51cbdc54678b...|9ef432eb625129730...|   delivered|     2017-10-02 10:56:33|2017-10-02 11:07:15|         2017-10-04 19:55:00|          2017-10-10 21:25:13|          2017-10-18 00:00:00|
# |53cdb2fc8bc7dce0b...|b0830fb4747a6c6d2...|   delivered|     2018-07-24 20:41:37|2018-07-26 03:24:27|         2018-07-26 14:31:00|          2018-08-07 15:27:45|          2018-08-13 00:00:00|
# |47770eb9100c2d0c4...|41ce2a54c0b03bf34...|   delivered|     2018-08-08 08:38:49|2018-08-08 08:55:23|         2018-08-08 13:50:00|          2018-08-17 18:06:29|          2018-09-04 00:00:00|
# |949d5b44dbf5de918...|f88197465ea7920ad...|   delivered|     2017-11-18 19:28:06|2017-11-18 19:45:59|         2017-11-22 13:39:59|          2017-12-02 00:28:42|          2017-12-15 00:00:00|
# |ad21c59c0840e6cb8...|8ab97904e6daea886...|   delivered|     2018-02-13 21:18:39|2018-02-13 22:20:29|         2018-02-14 19:46:34|          2018-02-16 18:17:02|          2018-02-26 00:00:00|
# |a4591c265e18cb1dc...|503740e9ca751ccdd...|   delivered|     2017-07-09 21:57:05|2017-07-09 22:10:13|         2017-07-11 14:58:04|          2017-07-26 10:57:55|          2017-08-01 00:00:00|
# |136cce7faa42fdb2c...|ed0271e0b7da060a3...|    invoiced|     2017-04-11 12:22:08|2017-04-13 13:25:17|                        NULL|                         NULL|          2017-05-09 00:00:00|
# |6514b8ad8028c9f2c...|9bdf08b4b3b52b552...|   delivered|     2017-05-16 13:10:30|2017-05-16 13:22:11|         2017-05-22 10:07:46|          2017-05-26 12:55:51|          2017-06-07 00:00:00|
# |76c6e866289321a7c...|f54a9f0e6b351c431...|   delivered|     2017-01-23 18:29:09|2017-01-25 02:50:47|         2017-01-26 14:16:31|          2017-02-02 14:08:10|          2017-03-06 00:00:00|
# |e69bfb5eb88e0ed6a...|31ad1d1b63eb99624...|   delivered|     2017-07-29 11:55:02|2017-07-29 12:05:32|         2017-08-10 19:45:24|          2017-08-16 17:14:30|          2017-08-23 00:00:00|
# |e6ce16cb79ec1d90b...|494dded5b201313c6...|   delivered|     2017-05-16 19:41:10|2017-05-16 19:50:18|         2017-05-18 11:40:40|          2017-05-29 11:18:31|          2017-06-07 00:00:00|
# |34513ce0c4fab462a...|7711cf624183d843a...|   delivered|     2017-07-13 19:58:11|2017-07-13 20:10:08|         2017-07-14 18:43:29|          2017-07-19 14:04:48|          2017-08-08 00:00:00|
# |82566a660a982b15f...|d3e3b74c766bc6214...|   delivered|     2018-06-07 10:06:19|2018-06-09 03:13:12|         2018-06-11 13:29:00|          2018-06-19 12:05:52|          2018-07-18 00:00:00|
# |5ff96c15d0b717ac6...|19402a48fe860416a...|   delivered|     2018-07-25 17:44:10|2018-07-25 17:55:14|         2018-07-26 13:16:00|          2018-07-30 15:52:25|          2018-08-08 00:00:00|
# |432aaf21d85167c2c...|3df704f53d3f1d481...|   delivered|     2018-03-01 14:14:28|2018-03-01 15:10:47|         2018-03-02 21:09:20|          2018-03-12 23:36:26|          2018-03-21 00:00:00|
# |dcb36b511fcac050b...|3b6828a50ffe54694...|   delivered|     2018-06-07 19:03:12|2018-06-12 23:31:02|         2018-06-11 14:54:00|          2018-06-21 15:34:32|          2018-07-04 00:00:00|
# |403b97836b0c04a62...|738b086814c6fcc74...|   delivered|     2018-01-02 19:00:43|2018-01-02 19:09:04|         2018-01-03 18:19:09|          2018-01-20 01:38:59|          2018-02-06 00:00:00|
# |116f0b09343b49556...|3187789bec9909876...|   delivered|     2017-12-26 23:41:31|2017-12-26 23:50:22|         2017-12-28 18:33:05|          2018-01-08 22:36:36|          2018-01-29 00:00:00|
# |85ce859fd6dc634de...|059f7fc5719c7da6c...|   delivered|     2017-11-21 00:03:41|2017-11-21 00:14:22|         2017-11-23 21:32:26|          2017-11-27 18:28:00|          2017-12-11 00:00:00|
# |83018ec114eee8641...|7f8c8b9c2ae27bf33...|   delivered|     2017-10-26 15:54:26|2017-10-26 16:08:14|         2017-10-26 21:46:53|          2017-11-08 22:22:00|          2017-11-23 00:00:00|
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# only showing top 20 rows

# %%
order_delivery_times=orders_df.select('order_id','order_purchase_timestamp','order_delivered_customer_date')\
.withColumn('delivery_time_taken',datediff(orders_df['order_delivered_customer_date'],orders_df['order_purchase_timestamp'])).orderBy(col('delivery_time_taken').desc())

order_delivery_times.show()
# Out:
# +--------------------+------------------------+-----------------------------+-------------------+
# |            order_id|order_purchase_timestamp|order_delivered_customer_date|delivery_time_taken|
# +--------------------+------------------------+-----------------------------+-------------------+
# |ca07593549f1816d2...|     2017-02-21 23:31:27|          2017-09-19 14:36:39|                210|
# |1b3190b2dfa9d789e...|     2018-02-23 14:57:35|          2018-09-19 23:24:07|                208|
# |440d0d17af552815d...|     2017-03-07 23:59:51|          2017-09-19 15:12:50|                196|
# |2fb597c2f772eca01...|     2017-03-08 18:09:02|          2017-09-19 14:33:17|                195|
# |285ab9426d6982034...|     2017-03-08 22:47:40|          2017-09-19 14:00:04|                195|
# |0f4519c5f1c541dde...|     2017-03-09 13:26:57|          2017-09-19 14:38:21|                194|
# |47b40429ed8cce3ae...|     2018-01-03 09:44:01|          2018-07-13 20:51:31|                191|
# |2fe324febf907e3ea...|     2017-03-13 20:17:10|          2017-09-19 17:00:07|                190|
# |2d7561026d542c8db...|     2017-03-15 11:24:27|          2017-09-19 14:38:18|                188|
# |c27815f7e3dd0b926...|     2017-03-15 23:23:17|          2017-09-19 17:14:25|                188|
# |437222e3fd1b07396...|     2017-03-16 11:36:00|          2017-09-19 16:28:58|                187|
# |dfe5f68118c257614...|     2017-03-17 12:32:22|          2017-09-19 18:13:19|                186|
# |6e82dcfb5eada6283...|     2017-05-17 19:09:02|          2017-11-16 10:56:45|                183|
# |2ba1366baecad3c35...|     2017-02-28 14:56:37|          2017-08-28 16:23:46|                181|
# |d24e8541128cea179...|     2017-06-12 13:14:11|          2017-12-04 18:36:29|                175|
# |3566eabb132f8d647...|     2017-03-29 13:57:55|          2017-09-19 15:07:09|                174|
# |ed8e9faf1b75f43ee...|     2017-11-29 15:10:14|          2018-05-21 18:22:18|                173|
# |2fa29503f2ebd9f53...|     2017-03-31 15:03:51|          2017-09-19 18:24:46|                172|
# |4fbc8d6f2f4db3e78...|     2018-02-02 21:38:36|          2018-07-20 23:37:50|                168|
# |525e11b26fdb7f414...|     2017-04-04 16:19:10|          2017-09-19 14:58:10|                168|
# +--------------------+------------------------+-----------------------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# **standardizing format**

# %%
def print_schema(df,df_name):
    print(f"schema of {df_name}")
    df.printSchema()

# %%
print_schema(orders_df,'orders')
# Out:
# schema of orders
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- order_status: string (nullable = true)
#  |-- order_purchase_timestamp: timestamp (nullable = true)
#  |-- order_approved_at: timestamp (nullable = true)
#  |-- order_delivered_carrier_date: timestamp (nullable = true)
#  |-- order_delivered_customer_date: timestamp (nullable = true)
#  |-- order_estimated_delivery_date: timestamp (nullable = true)

# %%
print_schema(customer_df,'customers')
# Out:
# schema of customers
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_unique_id: string (nullable = true)
#  |-- customer_zip_code_prefix: integer (nullable = true)
#  |-- customer_city: string (nullable = true)
#  |-- customer_state: string (nullable = true)

# %%
print_schema(order_payments_df,'orders payments')
# Out:
# schema of orders payments
# root
#  |-- order_id: string (nullable = true)
#  |-- payment_sequential: integer (nullable = true)
#  |-- payment_type: string (nullable = true)
#  |-- payment_installments: integer (nullable = true)
#  |-- payment_value: double (nullable = true)

# %%
orders_df_cleaned=orders_df.withColumn('order_purchase_timestamp',to_date('order_purchase_timestamp'))

# %%
orders_df_cleaned.show()
# Out:
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# |            order_id|         customer_id|order_status|order_purchase_timestamp|  order_approved_at|order_delivered_carrier_date|order_delivered_customer_date|order_estimated_delivery_date|
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# |e481f51cbdc54678b...|9ef432eb625129730...|   delivered|              2017-10-02|2017-10-02 11:07:15|         2017-10-04 19:55:00|          2017-10-10 21:25:13|          2017-10-18 00:00:00|
# |53cdb2fc8bc7dce0b...|b0830fb4747a6c6d2...|   delivered|              2018-07-24|2018-07-26 03:24:27|         2018-07-26 14:31:00|          2018-08-07 15:27:45|          2018-08-13 00:00:00|
# |47770eb9100c2d0c4...|41ce2a54c0b03bf34...|   delivered|              2018-08-08|2018-08-08 08:55:23|         2018-08-08 13:50:00|          2018-08-17 18:06:29|          2018-09-04 00:00:00|
# |949d5b44dbf5de918...|f88197465ea7920ad...|   delivered|              2017-11-18|2017-11-18 19:45:59|         2017-11-22 13:39:59|          2017-12-02 00:28:42|          2017-12-15 00:00:00|
# |ad21c59c0840e6cb8...|8ab97904e6daea886...|   delivered|              2018-02-13|2018-02-13 22:20:29|         2018-02-14 19:46:34|          2018-02-16 18:17:02|          2018-02-26 00:00:00|
# |a4591c265e18cb1dc...|503740e9ca751ccdd...|   delivered|              2017-07-09|2017-07-09 22:10:13|         2017-07-11 14:58:04|          2017-07-26 10:57:55|          2017-08-01 00:00:00|
# |136cce7faa42fdb2c...|ed0271e0b7da060a3...|    invoiced|              2017-04-11|2017-04-13 13:25:17|                        NULL|                         NULL|          2017-05-09 00:00:00|
# |6514b8ad8028c9f2c...|9bdf08b4b3b52b552...|   delivered|              2017-05-16|2017-05-16 13:22:11|         2017-05-22 10:07:46|          2017-05-26 12:55:51|          2017-06-07 00:00:00|
# |76c6e866289321a7c...|f54a9f0e6b351c431...|   delivered|              2017-01-23|2017-01-25 02:50:47|         2017-01-26 14:16:31|          2017-02-02 14:08:10|          2017-03-06 00:00:00|
# |e69bfb5eb88e0ed6a...|31ad1d1b63eb99624...|   delivered|              2017-07-29|2017-07-29 12:05:32|         2017-08-10 19:45:24|          2017-08-16 17:14:30|          2017-08-23 00:00:00|
# |e6ce16cb79ec1d90b...|494dded5b201313c6...|   delivered|              2017-05-16|2017-05-16 19:50:18|         2017-05-18 11:40:40|          2017-05-29 11:18:31|          2017-06-07 00:00:00|
# |34513ce0c4fab462a...|7711cf624183d843a...|   delivered|              2017-07-13|2017-07-13 20:10:08|         2017-07-14 18:43:29|          2017-07-19 14:04:48|          2017-08-08 00:00:00|
# |82566a660a982b15f...|d3e3b74c766bc6214...|   delivered|              2018-06-07|2018-06-09 03:13:12|         2018-06-11 13:29:00|          2018-06-19 12:05:52|          2018-07-18 00:00:00|
# |5ff96c15d0b717ac6...|19402a48fe860416a...|   delivered|              2018-07-25|2018-07-25 17:55:14|         2018-07-26 13:16:00|          2018-07-30 15:52:25|          2018-08-08 00:00:00|
# |432aaf21d85167c2c...|3df704f53d3f1d481...|   delivered|              2018-03-01|2018-03-01 15:10:47|         2018-03-02 21:09:20|          2018-03-12 23:36:26|          2018-03-21 00:00:00|
# |dcb36b511fcac050b...|3b6828a50ffe54694...|   delivered|              2018-06-07|2018-06-12 23:31:02|         2018-06-11 14:54:00|          2018-06-21 15:34:32|          2018-07-04 00:00:00|
# |403b97836b0c04a62...|738b086814c6fcc74...|   delivered|              2018-01-02|2018-01-02 19:09:04|         2018-01-03 18:19:09|          2018-01-20 01:38:59|          2018-02-06 00:00:00|
# |116f0b09343b49556...|3187789bec9909876...|   delivered|              2017-12-26|2017-12-26 23:50:22|         2017-12-28 18:33:05|          2018-01-08 22:36:36|          2018-01-29 00:00:00|
# |85ce859fd6dc634de...|059f7fc5719c7da6c...|   delivered|              2017-11-21|2017-11-21 00:14:22|         2017-11-23 21:32:26|          2017-11-27 18:28:00|          2017-12-11 00:00:00|
# |83018ec114eee8641...|7f8c8b9c2ae27bf33...|   delivered|              2017-10-26|2017-10-26 16:08:14|         2017-10-26 21:46:53|          2017-11-08 22:22:00|          2017-11-23 00:00:00|
# +--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+
# only showing top 20 rows

# %%
orders_payments_cleaned=order_payments_df.withColumn('payment_type',when(col('payment_type')=='boleto','bank transfer').when(col('payment_type')=='debit_card','debit transfer')\
                                               .when(col('payment_type')=='credit_card','credit transfer').otherwise('other transfer'))
orders_payments_cleaned.show()
# Out:
# +--------------------+------------------+---------------+--------------------+-------------+
# |            order_id|payment_sequential|   payment_type|payment_installments|payment_value|
# +--------------------+------------------+---------------+--------------------+-------------+
# |b81ef226f3fe1789b...|                 1|credit transfer|                   8|        99.33|
# |a9810da82917af2d9...|                 1|credit transfer|                   1|        24.39|
# |25e8ea4e93396b6fa...|                 1|credit transfer|                   1|        65.71|
# |ba78997921bbcdc13...|                 1|credit transfer|                   8|       107.78|
# |42fdf880ba16b47b5...|                 1|credit transfer|                   2|       128.45|
# |298fcdf1f73eb413e...|                 1|credit transfer|                   2|        96.12|
# |771ee386b001f0620...|                 1|credit transfer|                   1|        81.16|
# |3d7239c394a212faa...|                 1|credit transfer|                   3|        51.84|
# |1f78449c87a54faf9...|                 1|credit transfer|                   6|       341.09|
# |0573b5e23cbd79800...|                 1|  bank transfer|                   1|        51.95|
# |d88e0d5fa41661ce0...|                 1|credit transfer|                   8|       188.73|
# |2480f727e869fdeb3...|                 1|credit transfer|                   1|        141.9|
# |616105c9352a9668c...|                 1|credit transfer|                   1|        75.78|
# |cf95215a722f3ebf2...|                 1|credit transfer|                   5|       102.66|
# |769214176682788a9...|                 1|credit transfer|                   4|       105.28|
# |12e5cfe0e4716b59a...|                 1|credit transfer|                  10|       157.45|
# |61059985a6fc0ad64...|                 1|credit transfer|                   1|       132.04|
# |79da3f5fe31ad1e45...|                 1|credit transfer|                   1|        98.94|
# |8ac09207f415d55ac...|                 1|credit transfer|                   4|       244.15|
# |b2349a3f20dfbeef6...|                 1|credit transfer|                   3|       136.71|
# +--------------------+------------------+---------------+--------------------+-------------+
# only showing top 20 rows

# %%
customer_df_cleaned=customer_df.withColumn('customer_zip_code_prefix',col('customer_zip_code_prefix').cast("string"))
customer_df_cleaned.printSchema()
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- customer_unique_id: string (nullable = true)
#  |-- customer_zip_code_prefix: string (nullable = true)
#  |-- customer_city: string (nullable = true)
#  |-- customer_state: string (nullable = true)

# %%
customer_df_cleaned=customer_df_cleaned.dropDuplicates(['customer_id'])

# %%
customer_df_cleaned.show()
# Out:
# [Stage 131:============================>                            (1 + 1) / 2]
# +--------------------+--------------------+------------------------+--------------------+--------------+
# |         customer_id|  customer_unique_id|customer_zip_code_prefix|       customer_city|customer_state|
# +--------------------+--------------------+------------------------+--------------------+--------------+
# |00012a2ce6f8dcda2...|248ffe10d632bebe4...|                    6273|              osasco|            SP|
# |000161a058600d590...|b0015e09bb4b6e47c...|                   35550|         itapecerica|            MG|
# |000379cdec6255224...|0b83f73b19c2019e1...|                    4841|           sao paulo|            SP|
# |0004164d20a9e969a...|104bdb7e6a6cdceaa...|                   13272|            valinhos|            SP|
# |000419c5494106c30...|14843983d4a159080...|                   24220|             niteroi|            RJ|
# |00050bf6e01e69d5c...|e3cf594a99e810f58...|                   98700|                ijui|            RS|
# |00072d033fe2e5906...|b7c13491fd2aecd93...|                   45026|vitoria da conquista|            BA|
# |000bf8121c3412d30...|1bc9b2dad6aefbfbc...|                   12335|             jacarei|            SP|
# |000fd45d6fedae68f...|cee6fa72fb403ef95...|                   12970|            piracaia|            SP|
# |001028b78fd413e19...|e57a935f49ffd73b9...|                    5387|           sao paulo|            SP|
# |001051abfcfdbed9f...|4ea5df5937187bd31...|                    2251|           sao paulo|            SP|
# |0012a5c13793cf51e...|48efc7def11f9a644...|                   20011|      rio de janeiro|            RJ|
# |00146ad3045499387...|5616f75d22507069b...|                   31060|      belo horizonte|            MG|
# |0015f7887e2fde13d...|866c923cde750dfc8...|                   25903|                mage|            RJ|
# |0017a0b4c1f1bdb9c...|e36a621e869b643b1...|                   81510|            curitiba|            PR|
# |001a57041f5640091...|163b27a06a32c2fa5...|                    2512|           sao paulo|            SP|
# |001c7f05398c45b42...|ba7ae7b528a2b8359...|                    6719|               cotia|            SP|
# |001f150aebb5d897f...|0f88eb431888ffb9d...|                   79031|        campo grande|            MS|
# |001f6f1a5e902ad14...|c6b7dcd3718d1ad87...|                   12460|    campos do jordao|            SP|
# |002905287304e28c0...|8bc183d9b9efac18f...|                   37578|       bueno brandao|            MG|
# +--------------------+--------------------+------------------------+--------------------+--------------+
# only showing top 20 rows

# %%
order_with_totalValues=orders_details.groupBy('order_id').agg(sum(col('payment_value')).alias('total_value')).orderBy(col('total_value').desc())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 order_with_totalValues=orders_details.groupBy('order_id').agg(sum(col('payment_value')).alias('total_value')).orderBy(col('total_value').desc())
#
# NameError: name 'orders_details' is not defined

# %%
order_with_totalValues.show()

# %% [markdown]
# **removing outliers**

# %%
quantiles=order_items_df.approxQuantile("price",[0.01,0.99],0.0)
low_cutoff,high_cutoff=quantiles[0],quantiles[1]

# %%
print(low_cutoff)
print(high_cutoff)
# Out:
# 9.99
# 890.0

# %%
order_items_df=order_items_df.filter((col('price')>low_cutoff) & (col('price')<high_cutoff))

# %%
products_df.printSchema()
# Out:
# root
#  |-- product_id: string (nullable = true)
#  |-- product_category_name: string (nullable = true)
#  |-- product_name_lenght: integer (nullable = true)
#  |-- product_description_lenght: integer (nullable = true)
#  |-- product_photos_qty: integer (nullable = true)
#  |-- product_weight_g: integer (nullable = true)
#  |-- product_length_cm: integer (nullable = true)
#  |-- product_height_cm: integer (nullable = true)
#  |-- product_width_cm: integer (nullable = true)

# %%
products_df=products_df.withColumn('product_size_category',when(col('product_weight_g')<500,'small').when(col('product_weight_g').between(500,2000),'medium').otherwise('large'))

# %%
products_df.show()
# Out:
# +--------------------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+---------------------+
# |          product_id|product_category_name|product_name_lenght|product_description_lenght|product_photos_qty|product_weight_g|product_length_cm|product_height_cm|product_width_cm|product_size_category|
# +--------------------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+---------------------+
# |1e9e8ef04dbcff454...|           perfumaria|                 40|                       287|                 1|             225|               16|               10|              14|                small|
# |3aa071139cb16b67c...|                artes|                 44|                       276|                 1|            1000|               30|               18|              20|               medium|
# |96bd76ec8810374ed...|        esporte_lazer|                 46|                       250|                 1|             154|               18|                9|              15|                small|
# |cef67bcfe19066a93...|                bebes|                 27|                       261|                 1|             371|               26|                4|              26|                small|
# |9dc1a7de274444849...| utilidades_domest...|                 37|                       402|                 4|             625|               20|               17|              13|               medium|
# |41d3672d4792049fa...| instrumentos_musi...|                 60|                       745|                 1|             200|               38|                5|              11|                small|
# |732bd381ad09e530f...|           cool_stuff|                 56|                      1272|                 4|           18350|               70|               24|              44|                large|
# |2548af3e6e77a690c...|     moveis_decoracao|                 56|                       184|                 2|             900|               40|                8|              40|               medium|
# |37cc742be07708b53...|     eletrodomesticos|                 57|                       163|                 1|             400|               27|               13|              17|                small|
# |8c92109888e8cdf9d...|           brinquedos|                 36|                      1156|                 1|             600|               17|               10|              12|               medium|
# |14aa47b7fe5c25522...|      cama_mesa_banho|                 54|                       630|                 1|            1100|               16|               10|              16|               medium|
# |03b63c5fc16691530...|                bebes|                 49|                       728|                 4|            7150|               50|               19|              45|                large|
# |cf55509ea8edaaac1...| instrumentos_musi...|                 43|                      1827|                 3|             250|               17|                7|              17|                small|
# |7bb6f29c2be577161...|     moveis_decoracao|                 51|                      2083|                 2|             600|               68|               11|              13|               medium|
# |eb31436580a610f20...| construcao_ferram...|                 59|                      1602|                 4|             200|               17|                7|              17|                small|
# |3bb7f144022e67327...|        esporte_lazer|                 22|                      3021|                 1|             800|               16|                2|              11|               medium|
# |6a2fb4dd53d2cdb88...|           perfumaria|                 39|                       346|                 2|             400|               27|                5|              20|                small|
# |a1b71017a84f92fd8...| informatica_acess...|                 59|                       636|                 1|             900|               40|               15|              20|               medium|
# |a0736b92e52f6cead...|     moveis_decoracao|                 56|                       296|                 2|            1700|              100|                7|              15|               medium|
# |f53103a77d9cf245e...|      cama_mesa_banho|                 52|                       206|                 1|             500|               16|               10|              16|               medium|
# +--------------------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+---------------------+
# only showing top 20 rows

# %%
#revenue per seller

sellers_df.printSchema()
# Out:
# root
#  |-- seller_id: string (nullable = true)
#  |-- seller_zip_code_prefix: integer (nullable = true)
#  |-- seller_city: string (nullable = true)
#  |-- seller_state: string (nullable = true)

# %%
order_payments_df.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- payment_sequential: integer (nullable = true)
#  |-- payment_type: string (nullable = true)
#  |-- payment_installments: integer (nullable = true)
#  |-- payment_value: double (nullable = true)

# %%
order_items_df.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- order_item_id: integer (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- seller_id: string (nullable = true)
#  |-- shipping_limit_date: timestamp (nullable = true)
#  |-- price: double (nullable = true)
#  |-- freight_value: double (nullable = true)

# %%
revenue_per_seller=order_items_df.groupBy('seller_id').agg(sum(col('price')).alias('revenue_generated')).orderBy(col('revenue_generated').desc())

# %%
revenue_per_seller.show()
# Out:
# +--------------------+------------------+
# |           seller_id| revenue_generated|
# +--------------------+------------------+
# |4869f7a5dfa277a7d...|226792.63999999908|
# |4a3ca9315b744ce9f...| 200472.9199999981|
# |7c67e1448b00f6e96...|187923.89000000118|
# |fa1c13f2614d7b5c4...| 162793.4399999999|
# |da8622b14eb17ae28...| 160196.9699999994|
# |7a67c85e85bb2ce85...|141645.63000000076|
# |1025f0e2d44d7041d...|138968.55000000005|
# |955fee9216a65b617...|135171.70000000007|
# |6560211a19b47992c...|123304.83000000002|
# |7e93a43ef30c4f03f...|121237.23000000011|
# |46dc3b2cc0980fb8e...|120611.24000000014|
# |620c87c171fb2a6dd...|114774.50000000048|
# |7d13fca1522535862...|113628.97000000006|
# |1f50f920176fa81da...|106939.21000000078|
# |cc419e0650a3c5ba7...|104053.41999999946|
# |a1043bafd471dff53...|101901.15999999992|
# |53243585a1d6dc264...| 95545.23000000005|
# |3d871de0142ce09b7...| 94914.20000000022|
# |5dceca129747e92ff...| 70817.41000000013|
# |ccc4bbb5f32a6ab2b...| 67885.54000000007|
# +--------------------+------------------+
# only showing top 20 rows

# %%
orders_details.write.mode('overwrite') \
    .option('path', '/data/project/cleaned_order_details.parquet') \
    .saveAsTable('order_details')
# Out:
# ivysettings.xml file not found in HIVE_HOME or HIVE_CONF_DIR,/etc/hive/conf.dist/ivysettings.xml will be used
# 25/11/11 16:34:06 WARN SessionState: METASTORE_FILTER_HOOK will be ignored, since hive.security.authorization.manager is set to instance of HiveAuthorizerFactory.

# %%
spark.sql('describe formatted order_details').show(truncate=False)
# Out:
# +-----------------------------+---------+-------+
# |col_name                     |data_type|comment|
# +-----------------------------+---------+-------+
# |customer_id                  |string   |NULL   |
# |order_id                     |string   |NULL   |
# |order_status                 |string   |NULL   |
# |order_purchase_timestamp     |date     |NULL   |
# |order_approved_at            |timestamp|NULL   |
# |order_delivered_carrier_date |timestamp|NULL   |
# |order_delivered_customer_date|timestamp|NULL   |
# |order_estimated_delivery_date|timestamp|NULL   |
# |order_item_id                |int      |NULL   |
# |product_id                   |string   |NULL   |
# |seller_id                    |string   |NULL   |
# |shipping_limit_date          |timestamp|NULL   |
# |price                        |double   |NULL   |
# |freight_value                |double   |NULL   |
# |payment_sequential           |int      |NULL   |
# |payment_type                 |string   |NULL   |
# |payment_installments         |int      |NULL   |
# |payment_value                |double   |NULL   |
# |customer_unique_id           |string   |NULL   |
# |customer_zip_code_prefix     |string   |NULL   |
# +-----------------------------+---------+-------+
# only showing top 20 rows

# %%
spark.sql("DESCRIBE FORMATTED order_details").show(100, truncate=False)
# Out:
# +-----------------------------+----------------------------------------------------------------+-------+
# |col_name                     |data_type                                                       |comment|
# +-----------------------------+----------------------------------------------------------------+-------+
# |customer_id                  |string                                                          |NULL   |
# |order_id                     |string                                                          |NULL   |
# |order_status                 |string                                                          |NULL   |
# |order_purchase_timestamp     |date                                                            |NULL   |
# |order_approved_at            |timestamp                                                       |NULL   |
# |order_delivered_carrier_date |timestamp                                                       |NULL   |
# |order_delivered_customer_date|timestamp                                                       |NULL   |
# |order_estimated_delivery_date|timestamp                                                       |NULL   |
# |order_item_id                |int                                                             |NULL   |
# |product_id                   |string                                                          |NULL   |
# |seller_id                    |string                                                          |NULL   |
# |shipping_limit_date          |timestamp                                                       |NULL   |
# |price                        |double                                                          |NULL   |
# |freight_value                |double                                                          |NULL   |
# |payment_sequential           |int                                                             |NULL   |
# |payment_type                 |string                                                          |NULL   |
# |payment_installments         |int                                                             |NULL   |
# |payment_value                |double                                                          |NULL   |
# |customer_unique_id           |string                                                          |NULL   |
# |customer_zip_code_prefix     |string                                                          |NULL   |
# |customer_city                |string                                                          |NULL   |
# |customer_state               |string                                                          |NULL   |
# |                             |                                                                |       |
# |# Detailed Table Information |                                                                |       |
# |Catalog                      |spark_catalog                                                   |       |
# |Database                     |default                                                         |       |
# |Table                        |order_details                                                   |       |
# |Owner                        |root                                                            |       |
# |Created Time                 |Tue Nov 11 16:34:08 UTC 2025                                    |       |
# |Last Access                  |UNKNOWN                                                         |       |
# |Created By                   |Spark 3.5.3                                                     |       |
# |Type                         |EXTERNAL                                                        |       |
# |Provider                     |parquet                                                         |       |
# |Statistics                   |18685257 bytes                                                  |       |
# |Location                     |hdfs://cluster-f354-m/data/project/cleaned_order_details.parquet|       |
# |Serde Library                |org.apache.hadoop.hive.ql.io.parquet.serde.ParquetHiveSerDe     |       |
# |InputFormat                  |org.apache.hadoop.hive.ql.io.parquet.MapredParquetInputFormat   |       |
# |OutputFormat                 |org.apache.hadoop.hive.ql.io.parquet.MapredParquetOutputFormat  |       |
# +-----------------------------+----------------------------------------------------------------+-------+

# %%
orders_df.cache()
customer_df.cache()
order_items_df.cache()
# Out:
# DataFrame[order_id: string, order_item_id: int, product_id: string, seller_id: string, shipping_limit_date: timestamp, price: double, freight_value: double]

# %%
products_df.printSchema()
# Out:
# root
#  |-- product_id: string (nullable = true)
#  |-- product_category_name: string (nullable = true)
#  |-- product_name_lenght: integer (nullable = true)
#  |-- product_description_lenght: integer (nullable = true)
#  |-- product_photos_qty: integer (nullable = true)
#  |-- product_weight_g: integer (nullable = true)
#  |-- product_length_cm: integer (nullable = true)
#  |-- product_height_cm: integer (nullable = true)
#  |-- product_width_cm: integer (nullable = true)

# %%
from pyspark.sql.functions import *

order_details=orders_df.join(order_items_df,'order_id','inner')\
.join(customer_df,'customer_id','inner')\
.join(products_df,'product_id','inner')\
.join(sellers_df,'seller_id','inner')\
.join(geolocation_df,col('customer_zip_code_prefix')==col('geolocation_zip_code_prefix'),'left')\
.join(order_reviews_df,'order_id','left')\
.join(order_payments_df,'order_id','left')

# %%
order_details.show()
# Out:
# [Stage 67:>                                                         (0 + 1) / 1]
# +--------------------+--------------------+--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+-------------+-------------------+-----+-------------+--------------------+------------------------+-------------+--------------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+----------------------+-----------+------------+---------------------------+-------------------+------------------+----------------+-----------------+--------------------+------------+--------------------+----------------------+--------------------+-----------------------+------------------+------------+--------------------+-------------+
# |            order_id|           seller_id|          product_id|         customer_id|order_status|order_purchase_timestamp|  order_approved_at|order_delivered_carrier_date|order_delivered_customer_date|order_estimated_delivery_date|order_item_id|shipping_limit_date|price|freight_value|  customer_unique_id|customer_zip_code_prefix|customer_city|customer_state|product_category_name|product_name_lenght|product_description_lenght|product_photos_qty|product_weight_g|product_length_cm|product_height_cm|product_width_cm|seller_zip_code_prefix|seller_city|seller_state|geolocation_zip_code_prefix|    geolocation_lat|   geolocation_lng|geolocation_city|geolocation_state|           review_id|review_score|review_comment_title|review_comment_message|review_creation_date|review_answer_timestamp|payment_sequential|payment_type|payment_installments|payment_value|
# +--------------------+--------------------+--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+-------------+-------------------+-----+-------------+--------------------+------------------------+-------------+--------------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+----------------------+-----------+------------+---------------------------+-------------------+------------------+----------------+-----------------+--------------------+------------+--------------------+----------------------+--------------------+-----------------------+------------------+------------+--------------------+-------------+
# |a29361cea3ac5ecb5...|b6d44737c04332870...|5a3320037d5922a77...|674a4d874e368f09a...|   delivered|     2018-02-25 15:39:46|2018-02-25 15:55:27|         2018-02-26 19:28:08|          2018-02-27 14:12:29|          2018-03-12 00:00:00|            1|2018-03-01 15:55:27| 79.0|        24.36|473d9165586cfc670...|                    2735|    sao paulo|            SP| utilidades_domest...|                 60|                       446|                 5|            4900|               36|               22|              36|                  9230|santo andre|          SP|                       2735|-23.493293256630533|-46.69275190643714|       sao paulo|               SP|9a64b06c734c7d2c2...|           5|                NULL|                  NULL| 2018-02-28 00:00:00|    2018-03-01 17:52:26|                 1| credit_card|                   1|       329.58|
# |a29361cea3ac5ecb5...|b6d44737c04332870...|5a3320037d5922a77...|674a4d874e368f09a...|   delivered|     2018-02-25 15:39:46|2018-02-25 15:55:27|         2018-02-26 19:28:08|          2018-02-27 14:12:29|          2018-03-12 00:00:00|            1|2018-03-01 15:55:27| 79.0|        24.36|473d9165586cfc670...|                    2735|    sao paulo|            SP| utilidades_domest...|                 60|                       446|                 5|            4900|               36|               22|              36|                  9230|santo andre|          SP|                       2735|-23.492484576461443| -46.6948057322985|       sao paulo|               SP|9a64b06c734c7d2c2...|           5|                NULL|                  NULL| 2018-02-28 00:00:00|    2018-03-01 17:52:26|                 1| credit_card|                   1|       329.58|
# |a29361cea3ac5ecb5...|b6d44737c04332870...|5a3320037d5922a77...|674a4d874e368f09a...|   delivered|     2018-02-25 15:39:46|2018-02-25 15:55:27|         2018-02-26 19:28:08|          2018-02-27 14:12:29|          2018-03-12 00:00:00|            1|2018-03-01 15:55:27| 79.0|        24.36|473d9165586cfc670...|                    2735|    sao paulo|            SP| utilidades_domest...|                 60|                       446|                 5|            4900|               36|               22|              36|                  9230|santo andre|          SP|                       2735| -23.49243356703377|-46.69480217086601|       sao paulo|               SP|9a64b06c734c7d2c2...|           5|                NULL|                  NULL| 2018-02-28 00:00:00|    2018-03-01 17:52:26|                 1| credit_card|                   1|       329.58|
# |a29361cea3ac5ecb5...|b6d44737c04332870...|5a3320037d5922a77...|674a4d874e368f09a...|   delivered|     2018-02-25 15:39:46|2018-02-25 15:55:27|         2018-02-26 19:28:08|          2018-02-27 14:12:29|          2018-03-12 00:00:00|            1|2018-03-01 15:55:27| 79.0|        24.36|473d9165586cfc670...|                    2735|    sao paulo|            SP| utilidades_domest...|                 60|                       446|                 5|            4900|               36|               22|              36|                  9230|santo andre|          SP|                       2735|-23.492846646362207|-46.69382495425785|       sao paulo|               SP|9a64b06c734c7d2c2...|           5|                NULL|                  NULL| 2018-02-28 00:00:00|    2018-03-01 17:52:26|                 1| credit_card|                   1|       329.58|
# |a29361cea3ac5ecb5...|b6d44737c04332870...|5a3320037d5922a77...|674a4d874e368f09a...|   delivered|     2018-02-25 15:39:46|2018-02-25 15:55:27|         2018-02-26 19:28:08|          2018-02-27 14:12:29|          2018-03-12 00:00:00|            1|2018-03-01 15:55:27| 79.0|        24.36|473d9165586cfc670...|                    2735|    sao paulo|            SP| utilidades_domest...|                 60|                       446|                 5|            4900|               36|               22|              36|                  9230|santo andre|          SP|                       2735|-23.492801882207214|-46.69255365669721|       sao paulo|               SP|9a64b06c734c7d2c2...|           5|                NULL|                  NULL| 2018-02-28 00:00:00|    2018-03-01 17:52:26|                 1| credit_card|                   1|       329.58|
# |a29361cea3ac5ecb5...|b6d44737c04332870...|5a3320037d5922a77...|674a4d874e368f09a...|   delivered|     2018-02-25 15:39:46|2018-02-25 15:55:27|         2018-02-26 19:28:08|          2018-02-27 14:12:29|          2018-03-12 00:00:00|            1|2018-03-01 15:55:27| 79.0|        24.36|473d9165586cfc670...|                    2735|    sao paulo|            SP| utilidades_domest...|                 60|                       446|                 5|            4900|               36|               22|              36|                  9230|santo andre|          SP|                       2735|  -23.4927595434244|-46.69382278282069|       sao paulo|               SP|9a64b06c734c7d2c2...|           5|                NULL|                  NULL| 2018-02-28 00:00:00|    2018-03-01 17:52:26|                 1| credit_card|                   1|       329.58|
# |a29361cea3ac5ecb5...|b6d44737c04332870...|5a3320037d5922a77...|674a4d874e368f09a...|   delivered|     2018-02-25 15:39:46|2018-02-25 15:55:27|         2018-02-26 19:28:08|          2018-02-27 14:12:29|          2018-03-12 00:00:00|            1|2018-03-01 15:55:27| 79.0|        24.36|473d9165586cfc670...|                    2735|    sao paulo|            SP| utilidades_domest...|                 60|                       446|                 5|            4900|               36|               22|              36|                  9230|santo andre|          SP|                       2735|  -23.4927595434244|-46.69382278282069|       sao paulo|               SP|9a64b06c734c7d2c2...|           5|                NULL|                  NULL| 2018-02-28 00:00:00|    2018-03-01 17:52:26|                 1| credit_card|                   1|       329.58|
# |a29361cea3ac5ecb5...|b6d44737c04332870...|5a3320037d5922a77...|674a4d874e368f09a...|   delivered|     2018-02-25 15:39:46|2018-02-25 15:55:27|         2018-02-26 19:28:08|          2018-02-27 14:12:29|          2018-03-12 00:00:00|            1|2018-03-01 15:55:27| 79.0|        24.36|473d9165586cfc670...|                    2735|    sao paulo|            SP| utilidades_domest...|                 60|                       446|                 5|            4900|               36|               22|              36|                  9230|santo andre|          SP|                       2735|-23.490147745928823|-46.69439651441664|       sao paulo|               SP|9a64b06c734c7d2c2...|           5|                NULL|                  NULL| 2018-02-28 00:00:00|    2018-03-01 17:52:26|                 1| credit_card|                   1|       329.58|
# |a29361cea3ac5ecb5...|b6d44737c04332870...|5a3320037d5922a77...|674a4d874e368f09a...|   delivered|     2018-02-25 15:39:46|2018-02-25 15:55:27|         2018-02-26 19:28:08|          2018-02-27 14:12:29|          2018-03-12 00:00:00|            1|2018-03-01 15:55:27| 79.0|        24.36|473d9165586cfc670...|                    2735|    sao paulo|            SP| utilidades_domest...|                 60|                       446|                 5|            4900|               36|               22|              36|                  9230|santo andre|          SP|                       2735|  -23.4927595434244|-46.69382278282069|       sao paulo|               SP|9a64b06c734c7d2c2...|           5|                NULL|                  NULL| 2018-02-28 00:00:00|    2018-03-01 17:52:26|                 1| credit_card|                   1|       329.58|
# |a29361cea3ac5ecb5...|b6d44737c04332870...|5a3320037d5922a77...|674a4d874e368f09a...|   delivered|     2018-02-25 15:39:46|2018-02-25 15:55:27|         2018-02-26 19:28:08|          2018-02-27 14:12:29|          2018-03-12 00:00:00|            1|2018-03-01 15:55:27| 79.0|        24.36|473d9165586cfc670...|                    2735|    sao paulo|            SP| utilidades_domest...|                 60|                       446|                 5|            4900|               36|               22|              36|                  9230|santo andre|          SP|                       2735|-23.493293256630533|-46.69275190643714|       sao paulo|               SP|9a64b06c734c7d2c2...|           5|                NULL|                  NULL| 2018-02-28 00:00:00|    2018-03-01 17:52:26|                 1| credit_card|                   1|       329.58|
# |a29361cea3ac5ecb5...|b6d44737c04332870...|5a3320037d5922a77...|674a4d874e368f09a...|   delivered|     2018-02-25 15:39:46|2018-02-25 15:55:27|         2018-02-26 19:28:08|          2018-02-27 14:12:29|          2018-03-12 00:00:00|            1|2018-03-01 15:55:27| 79.0|        24.36|473d9165586cfc670...|                    2735|    sao paulo|            SP| utilidades_domest...|                 60|                       446|                 5|            4900|               36|               22|              36|                  9230|santo andre|          SP|                       2735|-23.492578358041385| -46.6948293043452|       são paulo|               SP|9a64b06c734c7d2c2...|           5|                NULL|                  NULL| 2018-02-28 00:00:00|    2018-03-01 17:52:26|                 1| credit_card|                   1|       329.58|
# |a29361cea3ac5ecb5...|b6d44737c04332870...|5a3320037d5922a77...|674a4d874e368f09a...|   delivered|     2018-02-25 15:39:46|2018-02-25 15:55:27|         2018-02-26 19:28:08|          2018-02-27 14:12:29|          2018-03-12 00:00:00|            1|2018-03-01 15:55:27| 79.0|        24.36|473d9165586cfc670...|                    2735|    sao paulo|            SP| utilidades_domest...|                 60|                       446|                 5|            4900|               36|               22|              36|                  9230|santo andre|          SP|                       2735|-23.493293256630533|-46.69275190643714|       sao paulo|               SP|9a64b06c734c7d2c2...|           5|                NULL|                  NULL| 2018-02-28 00:00:00|    2018-03-01 17:52:26|                 1| credit_card|                   1|       329.58|
# |a29361cea3ac5ecb5...|b6d44737c04332870...|5a3320037d5922a77...|674a4d874e368f09a...|   delivered|     2018-02-25 15:39:46|2018-02-25 15:55:27|         2018-02-26 19:28:08|          2018-02-27 14:12:29|          2018-03-12 00:00:00|            1|2018-03-01 15:55:27| 79.0|        24.36|473d9165586cfc670...|                    2735|    sao paulo|            SP| utilidades_domest...|                 60|                       446|                 5|            4900|               36|               22|              36|                  9230|santo andre|          SP|                       2735|  -23.4927595434244|-46.69382278282069|       sao paulo|               SP|9a64b06c734c7d2c2...|           5|                NULL|                  NULL| 2018-02-28 00:00:00|    2018-03-01 17:52:26|                 1| credit_card|                   1|       329.58|
# |a29361cea3ac5ecb5...|b6d44737c04332870...|5a3320037d5922a77...|674a4d874e368f09a...|   delivered|     2018-02-25 15:39:46|2018-02-25 15:55:27|         2018-02-26 19:28:08|          2018-02-27 14:12:29|          2018-03-12 00:00:00|            1|2018-03-01 15:55:27| 79.0|        24.36|473d9165586cfc670...|                    2735|    sao paulo|            SP| utilidades_domest...|                 60|                       446|                 5|            4900|               36|               22|              36|                  9230|santo andre|          SP|                       2735|  -23.4927595434244|-46.69382278282069|       sao paulo|               SP|9a64b06c734c7d2c2...|           5|                NULL|                  NULL| 2018-02-28 00:00:00|    2018-03-01 17:52:26|                 1| credit_card|                   1|       329.58|
# |a29361cea3ac5ecb5...|b6d44737c04332870...|5a3320037d5922a77...|674a4d874e368f09a...|   delivered|     2018-02-25 15:39:46|2018-02-25 15:55:27|         2018-02-26 19:28:08|          2018-02-27 14:12:29|          2018-03-12 00:00:00|            1|2018-03-01 15:55:27| 79.0|        24.36|473d9165586cfc670...|                    2735|    sao paulo|            SP| utilidades_domest...|                 60|                       446|                 5|            4900|               36|               22|              36|                  9230|santo andre|          SP|                       2735| -23.49276948542905|-46.69284066180967|       sao paulo|               SP|9a64b06c734c7d2c2...|           5|                NULL|                  NULL| 2018-02-28 00:00:00|    2018-03-01 17:52:26|                 1| credit_card|                   1|       329.58|
# |a29361cea3ac5ecb5...|b6d44737c04332870...|5a3320037d5922a77...|674a4d874e368f09a...|   delivered|     2018-02-25 15:39:46|2018-02-25 15:55:27|         2018-02-26 19:28:08|          2018-02-27 14:12:29|          2018-03-12 00:00:00|            1|2018-03-01 15:55:27| 79.0|        24.36|473d9165586cfc670...|                    2735|    sao paulo|            SP| utilidades_domest...|                 60|                       446|                 5|            4900|               36|               22|              36|                  9230|santo andre|          SP|                       2735|  -23.4927595434244|-46.69382278282069|       sao paulo|               SP|9a64b06c734c7d2c2...|           5|                NULL|                  NULL| 2018-02-28 00:00:00|    2018-03-01 17:52:26|                 1| credit_card|                   1|       329.58|
# |a29361cea3ac5ecb5...|b6d44737c04332870...|5a3320037d5922a77...|674a4d874e368f09a...|   delivered|     2018-02-25 15:39:46|2018-02-25 15:55:27|         2018-02-26 19:28:08|          2018-02-27 14:12:29|          2018-03-12 00:00:00|            1|2018-03-01 15:55:27| 79.0|        24.36|473d9165586cfc670...|                    2735|    sao paulo|            SP| utilidades_domest...|                 60|                       446|                 5|            4900|               36|               22|              36|                  9230|santo andre|          SP|                       2735|  -23.4927595434244|-46.69382278282069|       sao paulo|               SP|9a64b06c734c7d2c2...|           5|                NULL|                  NULL| 2018-02-28 00:00:00|    2018-03-01 17:52:26|                 1| credit_card|                   1|       329.58|
# |a29361cea3ac5ecb5...|b6d44737c04332870...|5a3320037d5922a77...|674a4d874e368f09a...|   delivered|     2018-02-25 15:39:46|2018-02-25 15:55:27|         2018-02-26 19:28:08|          2018-02-27 14:12:29|          2018-03-12 00:00:00|            1|2018-03-01 15:55:27| 79.0|        24.36|473d9165586cfc670...|                    2735|    sao paulo|            SP| utilidades_domest...|                 60|                       446|                 5|            4900|               36|               22|              36|                  9230|santo andre|          SP|                       2735| -23.49268451283578|   -46.69268519046|       sao paulo|               SP|9a64b06c734c7d2c2...|           5|                NULL|                  NULL| 2018-02-28 00:00:00|    2018-03-01 17:52:26|                 1| credit_card|                   1|       329.58|
# |a29361cea3ac5ecb5...|b6d44737c04332870...|5a3320037d5922a77...|674a4d874e368f09a...|   delivered|     2018-02-25 15:39:46|2018-02-25 15:55:27|         2018-02-26 19:28:08|          2018-02-27 14:12:29|          2018-03-12 00:00:00|            1|2018-03-01 15:55:27| 79.0|        24.36|473d9165586cfc670...|                    2735|    sao paulo|            SP| utilidades_domest...|                 60|                       446|                 5|            4900|               36|               22|              36|                  9230|santo andre|          SP|                       2735|-23.493293256630533|-46.69275190643714|       sao paulo|               SP|9a64b06c734c7d2c2...|           5|                NULL|                  NULL| 2018-02-28 00:00:00|    2018-03-01 17:52:26|                 1| credit_card|                   1|       329.58|
# |a29361cea3ac5ecb5...|b6d44737c04332870...|5a3320037d5922a77...|674a4d874e368f09a...|   delivered|     2018-02-25 15:39:46|2018-02-25 15:55:27|         2018-02-26 19:28:08|          2018-02-27 14:12:29|          2018-03-12 00:00:00|            1|2018-03-01 15:55:27| 79.0|        24.36|473d9165586cfc670...|                    2735|    sao paulo|            SP| utilidades_domest...|                 60|                       446|                 5|            4900|               36|               22|              36|                  9230|santo andre|          SP|                       2735|-23.494231138847667|-46.69321079884529|       sao paulo|               SP|9a64b06c734c7d2c2...|           5|                NULL|                  NULL| 2018-02-28 00:00:00|    2018-03-01 17:52:26|                 1| credit_card|                   1|       329.58|
# +--------------------+--------------------+--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+-------------+-------------------+-----+-------------+--------------------+------------------------+-------------+--------------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+----------------------+-----------+------------+---------------------------+-------------------+------------------+----------------+-----------------+--------------------+------------+--------------------+----------------------+--------------------+-----------------------+------------------+------------+--------------------+-------------+
# only showing top 20 rows

# %%
order_details.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- seller_id: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- order_status: string (nullable = true)
#  |-- order_purchase_timestamp: timestamp (nullable = true)
#  |-- order_approved_at: timestamp (nullable = true)
#  |-- order_delivered_carrier_date: timestamp (nullable = true)
#  |-- order_delivered_customer_date: timestamp (nullable = true)
#  |-- order_estimated_delivery_date: timestamp (nullable = true)
#  |-- order_item_id: integer (nullable = true)
#  |-- shipping_limit_date: timestamp (nullable = true)
#  |-- price: double (nullable = true)
#  |-- freight_value: double (nullable = true)
#  |-- customer_unique_id: string (nullable = true)
#  |-- customer_zip_code_prefix: integer (nullable = true)
#  |-- customer_city: string (nullable = true)
#  |-- customer_state: string (nullable = true)
#  |-- product_category_name: string (nullable = true)
#  |-- product_name_lenght: integer (nullable = true)
#  |-- product_description_lenght: integer (nullable = true)
#  |-- product_photos_qty: integer (nullable = true)
#  |-- product_weight_g: integer (nullable = true)
#  |-- product_length_cm: integer (nullable = true)
#  |-- product_height_cm: integer (nullable = true)
#  |-- product_width_cm: integer (nullable = true)
#  |-- seller_zip_code_prefix: integer (nullable = true)
#  |-- seller_city: string (nullable = true)
#  |-- seller_state: string (nullable = true)
#  |-- geolocation_zip_code_prefix: integer (nullable = true)
#  |-- geolocation_lat: double (nullable = true)
#  |-- geolocation_lng: double (nullable = true)
#  |-- geolocation_city: string (nullable = true)
#  |-- geolocation_state: string (nullable = true)
#  |-- review_id: string (nullable = true)
#  |-- review_score: string (nullable = true)
#  |-- review_comment_title: string (nullable = true)
#  |-- review_comment_message: string (nullable = true)
#  |-- review_creation_date: string (nullable = true)
#  |-- review_answer_timestamp: string (nullable = true)
#  |-- payment_sequential: integer (nullable = true)
#  |-- payment_type: string (nullable = true)
#  |-- payment_installments: integer (nullable = true)
#  |-- payment_value: double (nullable = true)

# %%
order_details.groupBy('seller_id').agg(sum('price').alias('total_revenue')).orderBy(col('total_revenue').desc()).show()
# Out:
# [Stage 101:============================>                            (1 + 1) / 2]
# +--------------------+--------------------+
# |           seller_id|       total_revenue|
# +--------------------+--------------------+
# |4869f7a5dfa277a7d...| 3.613871731999314E7|
# |53243585a1d6dc264...|3.4291592950000696E7|
# |4a3ca9315b744ce9f...| 3.375957084001202E7|
# |7c67e1448b00f6e96...|3.2282321790021457E7|
# |fa1c13f2614d7b5c4...|3.0139386310006626E7|
# |da8622b14eb17ae28...| 2.985766973003611E7|
# |7e93a43ef30c4f03f...| 2.631570630000355E7|
# |1025f0e2d44d7041d...|2.2937518520012792E7|
# |46dc3b2cc0980fb8e...| 2.179177329001608E7|
# |955fee9216a65b617...|2.0964410670017645E7|
# |7a67c85e85bb2ce85...| 2.031279489002914E7|
# |620c87c171fb2a6dd...| 2.011983960002505E7|
# |7d13fca1522535862...|1.8156881910003982E7|
# |a1043bafd471dff53...|1.7662675980010696E7|
# |6560211a19b47992c...|1.7315932900000528E7|
# |edb1ef5e36e0c8cd8...|1.6624835150007125E7|
# |1f50f920176fa81da...|1.6497454440033637E7|
# |5dceca129747e92ff...|1.4910548340003535E7|
# |cc419e0650a3c5ba7...| 1.475146450003979E7|
# |3d871de0142ce09b7...|1.4184525300004762E7|
# +--------------------+--------------------+
# only showing top 20 rows

# %%
order_details.select(['order_id']).filter(col('order_item_id')>2).show(truncate=False)
# Out:
# +--------------------------------+
# |order_id                        |
# +--------------------------------+
# |00143d0f86d6fbd9f9b38ab440ac16f5|
# |00143d0f86d6fbd9f9b38ab440ac16f5|
# |00143d0f86d6fbd9f9b38ab440ac16f5|
# |00143d0f86d6fbd9f9b38ab440ac16f5|
# |00143d0f86d6fbd9f9b38ab440ac16f5|
# |00143d0f86d6fbd9f9b38ab440ac16f5|
# |00143d0f86d6fbd9f9b38ab440ac16f5|
# |00143d0f86d6fbd9f9b38ab440ac16f5|
# |00143d0f86d6fbd9f9b38ab440ac16f5|
# |00143d0f86d6fbd9f9b38ab440ac16f5|
# |00143d0f86d6fbd9f9b38ab440ac16f5|
# |00143d0f86d6fbd9f9b38ab440ac16f5|
# |00143d0f86d6fbd9f9b38ab440ac16f5|
# |00143d0f86d6fbd9f9b38ab440ac16f5|
# |00143d0f86d6fbd9f9b38ab440ac16f5|
# |00143d0f86d6fbd9f9b38ab440ac16f5|
# |00143d0f86d6fbd9f9b38ab440ac16f5|
# |00143d0f86d6fbd9f9b38ab440ac16f5|
# |00143d0f86d6fbd9f9b38ab440ac16f5|
# |00143d0f86d6fbd9f9b38ab440ac16f5|
# +--------------------------------+
# only showing top 20 rows

# %%
order_details.select('customer_id').filter(col('order_id')=='00143d0f86d6fbd9f9b38ab440ac16f5').show()
# Out:
# +--------------------+
# |         customer_id|
# +--------------------+
# |2e45292979b9b2700...|
# |2e45292979b9b2700...|
# |2e45292979b9b2700...|
# |2e45292979b9b2700...|
# |2e45292979b9b2700...|
# |2e45292979b9b2700...|
# |2e45292979b9b2700...|
# |2e45292979b9b2700...|
# |2e45292979b9b2700...|
# |2e45292979b9b2700...|
# |2e45292979b9b2700...|
# |2e45292979b9b2700...|
# |2e45292979b9b2700...|
# |2e45292979b9b2700...|
# |2e45292979b9b2700...|
# |2e45292979b9b2700...|
# |2e45292979b9b2700...|
# |2e45292979b9b2700...|
# |2e45292979b9b2700...|
# |2e45292979b9b2700...|
# +--------------------+
# only showing top 20 rows

# %%
#avg review score per seller

order_details.groupBy('seller_id').agg(avg(col('review_score')).alias('average_review')).orderBy(col('average_review').desc()).show()
# Out:
# [Stage 154:============================>                            (1 + 1) / 2]
# +--------------------+--------------+
# |           seller_id|average_review|
# +--------------------+--------------+
# |58c851d1a3c7cd3da...|           5.0|
# |aa8af66c623d7d544...|           5.0|
# |0f519b0d2e5eb2227...|           5.0|
# |31e60bf8d103ce479...|           5.0|
# |64c9a1db4e73e19aa...|           5.0|
# |2b2fed75b8e5ea3a0...|           5.0|
# |33ab10be054370c25...|           5.0|
# |9d213f303afae4983...|           5.0|
# |05a48cc8859962767...|           5.0|
# |94d76e96eedd97625...|           5.0|
# |e94b64dc6979b302a...|           5.0|
# |4aba6a02a788d3ec8...|           5.0|
# |fd312b6bf05efac6c...|           5.0|
# |a61cc04793308395a...|           5.0|
# |1a8e2d9c38b84a970...|           5.0|
# |edb58a1390adf2738...|           5.0|
# |c04d70d515d15a7e3...|           5.0|
# |5f57db27027655e6c...|           5.0|
# |c74f14c1e26cf1bd5...|           5.0|
# |2c538755f1ca9540a...|           5.0|
# +--------------------+--------------+
# only showing top 20 rows

# %%
#top products sold by number
order_details.groupBy('product_id').agg(count('product_id').alias('number_sold')).orderBy(col('number_sold').desc()).show()
# Out:
# [Stage 164:============================>                            (1 + 1) / 2]
# +--------------------+-----------+
# |          product_id|number_sold|
# +--------------------+-----------+
# |aca2eb7d00ea1a7b8...|      86740|
# |422879e10f4668299...|      81110|
# |99a4788cb24856965...|      78775|
# |389d119b48cf3043d...|      60248|
# |d1c427060a0f73f6b...|      59274|
# |368c6c730842d7801...|      58358|
# |53759a2ecddad2bb8...|      52654|
# |53b36df67ebb7c415...|      52105|
# |154e7e31ebfa09220...|      42700|
# |3dd2a17168ec895c7...|      40787|
# |e53e557d5a159f5aa...|      39516|
# |2b4609f8948be1887...|      36179|
# |35afc973633aaeb6b...|      31206|
# |e0d64dcfaa3b6db5c...|      31153|
# |42a2c92a0979a949c...|      30486|
# |7c1bd920dbdf22470...|      29018|
# |a62e25e09e05e6faf...|      28898|
# |5a848e4ab52fd5445...|      28737|
# |c4baedd846ed09b85...|      28166|
# |b532349fe46b38fbc...|      27176|
# +--------------------+-----------+
# only showing top 20 rows

# %%
#top customers by spending
order_details.groupBy('customer_id').agg(sum(col('price')).alias('amount_spent')).orderBy(col('amount_spent').desc()).show()
# Out:
# [Stage 176:============================>                            (1 + 1) / 2]
# +--------------------+------------------+
# |         customer_id|      amount_spent|
# +--------------------+------------------+
# |d3e82ccec3cb5f956...|         6662844.0|
# |df55c14d1476a9a34...|         3565657.0|
# |fe5113a38e3575c04...|         3293604.0|
# |ec5b2ba62e5743423...|         2556120.0|
# |63b964e79dee32a35...|         2501664.0|
# |46bb3c0b1a65c8399...|         2336752.0|
# |05455dfa7cd02f13d...| 2160194.400000087|
# |3690e975641f01bd0...|         2124498.0|
# |349509b216bd5ec11...|         1923627.0|
# |695476b5848d64ba0...|1820543.1299999943|
# |73236a0796f53d60d...|         1755520.0|
# |cc803a2c412833101...|         1676400.0|
# |1ff773612ab8934db...|1658641.7999999512|
# |fced842c7dad61e8c...|         1654898.0|
# |1ecb47d23dc8203cd...|1629588.3599999903|
# |de832e8dbb1f588a4...|1584990.5999999817|
# |803cd9b04f9cd252c...|         1512312.0|
# |d72181923840c8895...|1488114.8999999566|
# |06d478ba352a27a51...|         1461150.0|
# |0049e8442c2a3e4a8...|         1444800.0|
# +--------------------+------------------+
# only showing top 20 rows

# %%
orders_df.cache()
order_items_df.cache()
customer_df.cache()
# Out:
# DataFrame[customer_id: string, customer_unique_id: string, customer_zip_code_prefix: int, customer_city: string, customer_state: string]

# %%
geolocation_df=geolocation_df.dropDuplicates(['geolocation_zip_code_prefix'])

# %% [markdown]
# **ISSUE: We joined orders df with order items df, which was giving incorect results for stats like total orders per seller since order items df contains multiple rows with same order id
# but different order item id showing number of items purchased within each order. now we will make another col called total order value which will be calculated by summing up the price and freight value of each item.**

# %%
order_values=order_items_df.groupBy('order_id').agg(first(col('seller_id')).alias('seller_id'),first(col('product_id')).alias('product_id'),sum(col('price')).alias('total_price'),sum(col('freight_value')).alias('total_freight_value')).withColumn('total_value',round(col('total_price')+col('total_freight_value'),2))
order_values.show()
# Out:
# [Stage 130:============================>                            (1 + 1) / 2]
# +--------------------+--------------------+--------------------+------------------+-------------------+-----------+
# |            order_id|           seller_id|          product_id|       total_price|total_freight_value|total_value|
# +--------------------+--------------------+--------------------+------------------+-------------------+-----------+
# |000229ec398224ef6...|5b51032eddd242adc...|c777355d18b72b67a...|             199.0|              17.87|     216.87|
# |00054e8431b9d7675...|7040e82f899a04d1b...|8d4f2bb7e93e6710a...|              19.9|              11.85|      31.75|
# |000576fe39319847c...|5996cddab893a4652...|557d850972a7d6f79...|             810.0|              70.75|     880.75|
# |0005a1a1728c9d785...|a416b6a846a117243...|310ae3c140ff94b03...|            145.95|              11.65|      157.6|
# |0005f50442cb953dc...|ba143b05f0110f0dc...|4535b0e1091c278df...|             53.99|               11.4|      65.39|
# |00061f2a7bc09da83...|cc419e0650a3c5ba7...|d63c1011f49d98b97...|             59.99|               8.88|      68.87|
# |0006ec9db01a64e59...|4a3ca9315b744ce9f...|99a4788cb24856965...|              74.0|              23.32|      97.32|
# |0009792311464db53...|530ec6109d11eaaf8...|8cab8abac59158715...|              99.9|              27.65|     127.55|
# |0009c9a17f916a706...|fcb5ace8bcc92f757...|3f27ac8e699df3d30...|             639.0|              11.34|     650.34|
# |000aed2e25dbad2f9...|fe2032dab1a61af87...|4fa33915031a8cde0...|             144.0|               8.77|     152.77|
# |000c3e6612759851c...|218d46b86c1881d02...|b50c950aba0dcead2...|              99.0|              13.71|     112.71|
# |000e562887b1f2006...|8cbac7e12637ed9cf...|5ed9eaf534f6936b5...|              25.0|              16.11|      41.11|
# |000e906b789b55f64...|ea8482cd71df3c196...|57d79905de06d8897...|             21.99|              11.85|      33.84|
# |000f25f4d72195062...|7c67e1448b00f6e96...|1c05e0964302b6cf6...|            119.99|               44.4|     164.39|
# |0010b2e5201cc5f1a...|3504c0cb71d7fa48d...|5a419dbf24a8c9718...|              48.9|               16.6|       65.5|
# |00119ff934e539cf2...|c864036feaab8c165...|21b1c2f67a9aafb5a...|             219.9|              16.98|     236.88|
# |0011d82c4b53e22e8...|bfd27a966d91cfaaf...|c389f712c4b4510bc...|             289.0|              26.33|     315.33|
# |00130c0eee84a3d90...|16090f2ca825584b5...|89321f94e35fc6d79...|              27.9|               7.94|      35.84|
# |001427c0ec99cf8af...|77530e9772f57a62c...|28b4eced95a52d9c4...|              59.9|              23.35|      83.25|
# |00143d0f86d6fbd9f...|a17f621c590ea0fab...|e95ee6822b66ac605...|63.989999999999995|               45.3|     109.29|
# +--------------------+--------------------+--------------------+------------------+-------------------+-----------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import *

order_details=orders_df.join(order_values,'order_id','inner')\
.join(customer_df,'customer_id','inner')\
.join(products_df,'product_id','inner')\
.join(broadcast(sellers_df),'seller_id','inner')\
.join(broadcast(geolocation_df),col('customer_zip_code_prefix')==col('geolocation_zip_code_prefix'),'left')\
.join(broadcast(order_reviews_df),'order_id','left')

# %%
order_payments_df.groupBy('order_id').count().orderBy(col('count').desc()).show(truncate=False)
# Out:
# +--------------------------------+-----+
# |order_id                        |count|
# +--------------------------------+-----+
# |fa65dad1b0e818e3ccc5cb0e39231352|29   |
# |ccf804e764ed5650cd8759557269dc13|26   |
# |285c2e15bebd4ac83635ccc563dc71f4|22   |
# |895ab968e7bb0d5659d16cd74cd1650c|21   |
# |fedcd9f7ccdc8cba3a18defedd1a5547|19   |
# |ee9ca989fc93ba09a6eddc250ce01742|19   |
# |21577126c19bf11a0b91592e5844ba78|15   |
# |4bfcba9e084f46c8e3cb49b0fa6e6159|15   |
# |4689b1816de42507a7d63a4617383c59|14   |
# |3c58bffb70dcf45f12bdf66a3c215905|14   |
# |73df5d6adbeea12c8ae03df93f346e86|13   |
# |cf101c3abd3c061ca9f78c1bbb1125af|13   |
# |4fb76fa13b108a0d0478483421b0992c|13   |
# |6d58638e32674bebee793a47ac4cbadc|12   |
# |1d9a9731b9c10fc9cba74e6f74782e8b|12   |
# |1a611328643ae11146ba09a4425d2e12|12   |
# |d744783ed2ace06cac647a9e64dcbcfd|12   |
# |465c2e1bee4561cb39e0db8c5993aafc|12   |
# |c6492b842ac190db807c15aff21a7dd6|12   |
# |67d83bd36ec2c7fb557742fb58837659|12   |
# +--------------------------------+-----+
# only showing top 20 rows

# %%
order_values.count()
# Out:
# 98666

# %%
order_payments_df.filter(col('order_id')=='fa65dad1b0e818e3ccc5cb0e39231352').show()
# Out:
# +--------------------+------------------+------------+--------------------+-------------+
# |            order_id|payment_sequential|payment_type|payment_installments|payment_value|
# +--------------------+------------------+------------+--------------------+-------------+
# |fa65dad1b0e818e3c...|                27|     voucher|                   1|        66.02|
# |fa65dad1b0e818e3c...|                 4|     voucher|                   1|        29.16|
# |fa65dad1b0e818e3c...|                 1|     voucher|                   1|         3.71|
# |fa65dad1b0e818e3c...|                 9|     voucher|                   1|         1.08|
# |fa65dad1b0e818e3c...|                10|     voucher|                   1|        12.86|
# |fa65dad1b0e818e3c...|                 2|     voucher|                   1|         8.51|
# |fa65dad1b0e818e3c...|                25|     voucher|                   1|         3.68|
# |fa65dad1b0e818e3c...|                 5|     voucher|                   1|         0.66|
# |fa65dad1b0e818e3c...|                 6|     voucher|                   1|         5.02|
# |fa65dad1b0e818e3c...|                11|     voucher|                   1|         4.03|
# |fa65dad1b0e818e3c...|                14|     voucher|                   1|          0.0|
# |fa65dad1b0e818e3c...|                29|     voucher|                   1|        19.26|
# |fa65dad1b0e818e3c...|                28|     voucher|                   1|        29.05|
# |fa65dad1b0e818e3c...|                15|     voucher|                   1|        14.04|
# |fa65dad1b0e818e3c...|                 3|     voucher|                   1|         2.95|
# |fa65dad1b0e818e3c...|                 8|     voucher|                   1|        26.02|
# |fa65dad1b0e818e3c...|                12|     voucher|                   1|          3.6|
# |fa65dad1b0e818e3c...|                21|     voucher|                   1|         4.11|
# |fa65dad1b0e818e3c...|                19|     voucher|                   1|         5.02|
# |fa65dad1b0e818e3c...|                13|     voucher|                   1|          0.0|
# +--------------------+------------------+------------+--------------------+-------------+
# only showing top 20 rows

# %%
order_items_df.select('order_id').distinct().count()
# Out:
# 98666

# %%
order_details.count()
# Out:
# 98666

# %%
products_df.count()
# Out:
# 32951

# %%
orders_df.count()
# Out:
# 99441

# %%
geolocation_df.count()
# Out:
# 1000163

# %%
sellers_df.select('seller_id').distinct().count()
# Out:
# 3095

# %%
geolocation_df.count()
# Out:
# 19015

# %%
geolocation_df.select('geolocation_zip_code_prefix').distinct().count()
# Out:
# 19015

# %%
order_reviews_df.count()
# Out:
# 99742

# %%
order_reviews_df.select('order_id').distinct().count()
# Out:
# 99743

# %%
order_reviews_df.groupBy('order_id').count().orderBy(col('count')).filter(col('count')>=2).show(200,truncate=False)
# Out:
# +---------------------------------------------------------------+-----+
# |order_id                                                       |count|
# +---------------------------------------------------------------+-----+
# |e9e7ebde60b33ca371a24f94a52fb499                               |2    |
# |059bbeb3477ed66fd7e670c3f879009a                               |2    |
# |169ab175fb915582d84c0c5c95bb0fe3                               |2    |
# |23afc00db0b1c005196306f02e1c1178                               |2    |
# |b6e5aa946acc4e29e7069510f28a0bce                               |2    |
# |64bbe3a7dae1ea0dae5ac315fe779596                               |2    |
# |e00ed9d20c3479f9f0e9727ca9d60946                               |2    |
# |2017-04-04 00:00:00                                            |2    |
# | ok                                                            |2    |
# |38e31ec9d0ed250702ede5bb610d963b                               |2    |
# |c7e1e46af92704b1c2e1924de96e7479                               |2    |
# |0b127810f86631fa896fd74a421045f8                               |2    |
# |21cb4961399b846b168d0358100f473b                               |2    |
# |8d42bc7cf9914679406f48db0e05e571                               |2    |
# |b798fc527c548bfa5f069b5b29195275                               |2    |
# |70c77e51e0f179d75a64a614135afb6a                               |2    |
# |2017-03-08 00:00:00                                            |2    |
# |468edfd1aeeeef023e6bba4943f2cdfb                               |2    |
# |3366858be589fddbcf6a199aab0058d4                               |2    |
# |bee4fbc438d2d48527e812cb6a1c8166                               |2    |
# |b77200a7cbfba12d399cea6ab05f0056                               |2    |
# | atrás dela é tipo um buraco. Nas imagens não mostravam isso. "|2    |
# |f3ee55bf50ef2f2318599425ef80107d                               |2    |
# |ee15d1d23898663a46ad1c4b08a45759                               |2    |
# |18fdcbdf78e62bac03cf30b6b9398087                               |2    |
# |06b2c7035561ef12b16045ef4bf459e2                               |2    |
# |0b5588f04551d90ee148462bb65dfddf                               |2    |
# |2e3258f81be08e497abb202cef0c0303                               |2    |
# |00 - NÂO CASAL PADRAO. QUERO TROCA URGENTE."                   |2    |
# |02e0b68852217f5715fb9cc885829454                               |2    |
# |64b474e9995eb9740db3190013984b6b                               |2    |
# |28fbe65f18578f91f026300af5e6bdbc                               |2    |
# |a17af8e6044c5ccaa87b1d97559dc554                               |2    |
# |b4b23a5f1e3af0a90cce47b18af0e612                               |2    |
# |715b8576b74d53796bcbb107a201eb55                               |2    |
# |f93a732712407c02dce5dd5088d0f47b                               |2    |
# |71717b68820ab37f844d6799422804d7                               |2    |
# |2017-02-09 00:00:00                                            |2    |
# |02355020fd0a40a0d56df9f6ff060413                               |2    |
# |c879dff70ad9d2d3c315fc40492c660e                               |2    |
# |f83c07d038cf7ce0132a5797f823e4fe                               |2    |
# |96f5be02bc9ffc589f3274500a64a7e2                               |2    |
# |bc8446f693e6c406e28d5cee739dc4cd                               |2    |
# |5a3b1c29a49756e75f1ef513383c0c12                               |2    |
# |14f75c9606fc12baa607bebe380d7237                               |2    |
# |e706d614326b76f48f24d82f86c0b2ed                               |2    |
# |f86e20fe6ce750c00d7ed08e8c67384f                               |2    |
# |09a38776c4e31230864f867821174daa                               |2    |
# |df926b7d1f6199f57548358c93ec9f39                               |2    |
# |2f8f31eb2f7b6572836d662a6625c8e4                               |2    |
# |9db5ceb6f107ae0944c19188c8869a03                               |2    |
# |3df55fc07ff463109ce0422439693aee                               |2    |
# |4703440eb9289d3769819920e98ec061                               |2    |
# |d14639e8e6808119a16fde091d30b2d2                               |2    |
# |2017-02-12 00:00:00                                            |2    |
# |23a2d8b0357730d4f9c50aa48773e9e9                               |2    |
# |75213e459cfe44a61c496c864e0a8c63                               |2    |
# |3ea8ef64da06a959e384edb7cb824c02                               |2    |
# |2017-07-28 00:00:00                                            |2    |
# |566f53fc7d36fa366f7e221468121877                               |2    |
# |246b14cc444e8a7df0afd80495dfa052                               |2    |
# |8b3c2785144e72ccba9b0213f0f1cd1e                               |2    |
# |157de1652c032429a625d034be79eeeb                               |2    |
# |ac08c0b67890296c7c7c10f34b81eea4                               |2    |
# |62adfd8a504d828f9dc9c184f2a236b8                               |2    |
# |2683346722c6565c6c79e08c8264f25f                               |2    |
# |2017-02-22 00:00:00                                            |2    |
# |10467788e05701fc7e9293f6cbed5c11                               |2    |
# |78cf5dc2baadfbac2c47c6ef7c2a2282                               |2    |
# |61b2314bd576f3d792e46e1d56e51ee6                               |2    |
# |ec0dc4b572563095782c3e96a9f4d205                               |2    |
# |2613fb342bec59126f9c5180a5bc95ec                               |2    |
# |1aa720b6963ff9b4b5bff9bc48b49a89                               |2    |
# |0176a6846bcb3b0d3aa3116a9a768597                               |2    |
# |3b132068223649635448d659e7826d12                               |2    |
# |2017-07-19 00:00:00                                            |2    |
# |171c9f9a5667b0bea55d8b78c27bc5bd                               |2    |
# |a4b276bd4a9eba543ec90cdf29a67308                               |2    |
# |77bd3f7f2fefbad1254911e90bc64158                               |2    |
# |2d4bc14df7f5eaf36d2ef6d9a5b7c0d8                               |2    |
# |110f23195a2ddb2ccaad30b37bfacbbf                               |2    |
# |aa20064eef8808d62ed9ac5286ec0796                               |2    |
# |a1b8aea9fd9e26a8644a65e1aaea8740                               |2    |
# |c4ca4450ac2974ba5eeb4832b7ec724a                               |2    |
# |1a271fc8bb3a9a776ae5c012bf017ac5                               |2    |
# |565b0bdb5bfef65df5a23890967586f6                               |2    |
# |34080c138f92d6ea70448a0403b25d00                               |2    |
# |66355bca3dfaa134e807687ade5d3330                               |2    |
# |4082016610cd8b53add011fe068c04b3                               |2    |
# |2ce757e7e2cf3442241e4646b3472dd0                               |2    |
# |273177c9b2d2eb2a68a77ee39e726b52                               |2    |
# |2143393cca994a4b8235bc1d67ded772                               |2    |
# |1a69d5fdff0003d4571dffa1a9a10967                               |2    |
# |64307ceb91666760cf3ff463618302fd                               |2    |
# |cba44aa41766f6210b875f576a4241e4                               |2    |
# |2b0e07b3ff6d3a2db9405022edc865c2                               |2    |
# |4863e15fa53273cc7219c58f5ffda4fb                               |2    |
# |5b0cbe028ba75896dcef147e3cfaae1b                               |2    |
# |e1f693a7777b9f6ff730a9d2b45a56cb                               |2    |
# |14fdbdfb8a3c7657649abbc004c434c5                               |2    |
# |2fcdb0c004a2a538d3dd724ea76916bd                               |2    |
# |ed273ac994e955e0c775eccb0a6512c0                               |2    |
# |56fcb6d24acb1b94dd4492f663187b69                               |2    |
# |9de38c42ea4d33af19aac6c4d6c4b146                               |2    |
# |c7c28a159a907d1d0ff580856daffa72                               |2    |
# |0db1181e0778609b581bf9a95b17f313                               |2    |
# |d43872a5beeeefe86421f622da91fb38                               |2    |
# |08bf75dcf867b9f13026785053e87052                               |2    |
# |7144ca093cbdecfdfc3e76d49da6ffb9                               |2    |
# |14d35062b86c2e1f69376af68e9e2a1e                               |2    |
# |2017-07-18 00:00:00                                            |2    |
# |ab71e5dff0ed652f1559e1860391bd22                               |2    |
# |fd95ae805c63c534f1a64589e102225e                               |2    |
# |6bb796381998e8a626006950f6ef8dc0                               |2    |
# |95efc26128229ac33bfc67d4fce8fa28                               |2    |
# |2018-03-01 00:00:00                                            |2    |
# |6b2f7dba402cf63ca207bbe2cc05ef67                               |2    |
# |fd61441ba2a7b57e6342862e779b10b0                               |2    |
# |2017-03-25 00:00:00                                            |2    |
# |964937fd838e5fb7488cf417d7b60747                               |2    |
# |4f68ed0836136db8064bf34ebb1965e2                               |2    |
# |8e0ace07f58e07d34ada126b1de0d6a1                               |2    |
# |013056cfe49763c6f66bda03396c5ee3                               |2    |
# |6318d8c5f6857de384c0b3186d036457                               |2    |
# |2017-10-22 00:00:00                                            |2    |
# |230429e6f253f9cd6561aad72ce7ee2f                               |2    |
# |b7fe42fc0d57642abd6b868ce754865c                               |2    |
# |1de86d094f7dd41cca13d246d3b7fd07                               |2    |
# |b37a7e90838d63c38152d2f8c432a726                               |2    |
# |5ddea4bc0239f874cd7d6fd398d6045a                               |2    |
# |8f32ee82ea0fe678bd4aae681f1637cc                               |2    |
# |ace3b21c5c57456d2e2215452829073b                               |2    |
# |91e6838f3091d5ea8d82bc61a52b5d58                               |2    |
# |ed81dbeb0cedad4d3d1f1551b06d6ca3                               |2    |
# |94f522c26f2681ad053b999e34e7b317                               |2    |
# |17df2cc060680fc1712991499b645cd2                               |2    |
# |69ad29a3aba936e80ea906bf73c631a8                               |2    |
# |03eba6d9fef8f5b3e811d4b5a7cca9cd                               |2    |
# |d61b915b69851aec8a8865f36cfd793e                               |2    |
# |8f5fac100b291e3c7c7c34ca50001b5a                               |2    |
# |f707ff2a9514dce20b267136b60af042                               |2    |
# |843be4a0dcdb9716de7652d53af4acab                               |2    |
# |075a544c5f4ed4bb75f82b160465fe76                               |2    |
# |1f63547f5743b270843ccf840f00108a                               |2    |
# |2017-10-29 00:00:00                                            |2    |
# |6f118f6a730ce35b230974f295f743f9                               |2    |
# |9cffda8a5be9e20be381cc47ef5e8e00                               |2    |
# +---------------------------------------------------------------+-----+
# only showing top 200 rows

# %%
order_reviews_df.filter(col('order_id')=='6f118f6a730ce35b230974f295f743f9').show()
# Out:
# +--------------------+--------------------+------------+--------------------+----------------------+--------------------+-----------------------+
# |           review_id|            order_id|review_score|review_comment_title|review_comment_message|review_creation_date|review_answer_timestamp|
# +--------------------+--------------------+------------+--------------------+----------------------+--------------------+-----------------------+
# |2b33838f229aecc9c...|6f118f6a730ce35b2...|           5|                NULL|                  NULL| 2018-02-08 00:00:00|    2018-02-09 09:18:42|
# |f51c9e02992e07691...|6f118f6a730ce35b2...|           5|                NULL|                  NULL| 2018-02-15 00:00:00|    2018-02-19 13:15:14|
# +--------------------+--------------------+------------+--------------------+----------------------+--------------------+-----------------------+

# %%
order_reviews_df=order_reviews_df.dropna(subset=['order_id'])

# %%
order_reviews_df.groupBy('order_id').count().orderBy(col('count').desc()).show(truncate=False)
# Out:
# +-------------------+-----+
# |order_id           |count|
# +-------------------+-----+
# |2017-12-19 00:00:00|16   |
# |2018-05-15 00:00:00|16   |
# |2018-02-24 00:00:00|15   |
# |2017-12-16 00:00:00|15   |
# |2018-04-11 00:00:00|14   |
# |2017-12-06 00:00:00|14   |
# |2018-08-18 00:00:00|14   |
# |2018-08-28 00:00:00|13   |
# |2018-08-17 00:00:00|12   |
# |2018-03-30 00:00:00|12   |
# |2018-08-04 00:00:00|11   |
# |2018-03-21 00:00:00|11   |
# |2018-05-10 00:00:00|11   |
# |2018-08-15 00:00:00|11   |
# |2018-06-21 00:00:00|11   |
# |2018-04-13 00:00:00|11   |
# |2018-01-27 00:00:00|11   |
# |2017-12-13 00:00:00|11   |
# |2018-05-23 00:00:00|11   |
# |2018-08-10 00:00:00|11   |
# +-------------------+-----+
# only showing top 20 rows

# %%
order_reviews_df=order_reviews_df.dropDuplicates(subset=['order_id'])

# %%
from pyspark.sql.functions import col, trim

orders_reviews_df = orders_reviews_df.withColumn('order_id', trim(col('order_id')))

# %%
orders_reviews_df = orders_reviews_df.filter(col('order_id').rlike('^[a-f0-9]{32}$'))

# %%
orders_reviews_df.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- order_status: string (nullable = true)
#  |-- order_purchase_timestamp: timestamp (nullable = true)
#  |-- order_approved_at: timestamp (nullable = true)
#  |-- order_delivered_carrier_date: timestamp (nullable = true)
#  |-- order_delivered_customer_date: timestamp (nullable = true)
#  |-- order_estimated_delivery_date: timestamp (nullable = true)

# %%
order_reviews_df.groupBy('order_id').count().orderBy(col('count').desc()).show(truncate=False)
# Out:
# +-------------------+-----+
# |order_id           |count|
# +-------------------+-----+
# |2017-12-19 00:00:00|16   |
# |2018-05-15 00:00:00|16   |
# |2018-02-24 00:00:00|15   |
# |2017-12-16 00:00:00|15   |
# |2018-04-11 00:00:00|14   |
# |2017-12-06 00:00:00|14   |
# |2018-08-18 00:00:00|14   |
# |2018-08-28 00:00:00|13   |
# |2018-08-17 00:00:00|12   |
# |2018-03-30 00:00:00|12   |
# |2018-08-04 00:00:00|11   |
# |2018-03-21 00:00:00|11   |
# |2018-05-10 00:00:00|11   |
# |2018-08-15 00:00:00|11   |
# |2018-06-21 00:00:00|11   |
# |2018-04-13 00:00:00|11   |
# |2018-01-27 00:00:00|11   |
# |2017-12-13 00:00:00|11   |
# |2018-05-23 00:00:00|11   |
# |2018-08-10 00:00:00|11   |
# +-------------------+-----+
# only showing top 20 rows

# %%
order_payments_df.count()
# Out:
# 103886

# %%
order_reviews_df.count()
# Out:
# 104162

# %%
from pyspark.sql.functions import *
customer_df.join(geolocation_df,col('customer_zip_code_prefix')==col('geolocation_zip_code_prefix'),'left').count()
# Out:
# 15083733

# %%
geolocation_df.groupBy("geolocation_zip_code_prefix").count().filter(col("count") > 1).show()
# Out:
# [Stage 78:=============================>                            (1 + 1) / 2]
# +---------------------------+-----+
# |geolocation_zip_code_prefix|count|
# +---------------------------+-----+
# |                       2122|   33|
# |                       2366|   33|
# |                       3918|   50|
# |                       4101|   72|
# |                       9852|  107|
# |                      13289|   61|
# |                      26087|  111|
# |                      28024|   95|
# |                       3226|   24|
# |                       4190|   52|
# |                      18201|   69|
# |                      20396|   11|
# |                       1303|  166|
# |                       6825|   22|
# |                       8257|   60|
# |                      13483|   83|
# |                      24855|   41|
# |                      25638|    2|
# |                       2443|   80|
# |                       2721|  149|
# +---------------------------+-----+
# only showing top 20 rows

# %%
from pyspark.sql.window import Window
window_spec=Window.partitionBy('seller_id').orderBy(desc('price'))

# %%
top_seller_products_df=order_details.withColumn('rank',rank().over(window_spec)).filter(col('rank')<=5)
top_seller_products_df.select('seller_id','price','rank').orderBy(col('seller_id').desc()).show(100)
# Out:
# [Stage 300:============================>                            (1 + 1) / 2]
# +--------------------+------+----+
# |           seller_id| price|rank|
# +--------------------+------+----+
# |ffff564a4f9085cd2...| 366.5|   1|
# |ffff564a4f9085cd2...| 114.5|   2|
# |ffff564a4f9085cd2...| 109.2|   3|
# |ffff564a4f9085cd2...|103.95|   4|
# |ffff564a4f9085cd2...| 82.95|   5|
# |fffd5413c0700ac82...| 636.0|   1|
# |fffd5413c0700ac82...| 298.6|   2|
# |fffd5413c0700ac82...| 298.6|   2|
# |fffd5413c0700ac82...| 298.6|   2|
# |fffd5413c0700ac82...| 298.6|   2|
# |fffd5413c0700ac82...| 298.6|   2|
# |ffeee66ac5d5a62fe...|129.99|   4|
# |ffeee66ac5d5a62fe...|149.99|   1|
# |ffeee66ac5d5a62fe...|149.99|   1|
# |ffeee66ac5d5a62fe...|149.99|   1|
# |ffeee66ac5d5a62fe...|129.99|   4|
# |ffeee66ac5d5a62fe...|129.99|   4|
# |ffeee66ac5d5a62fe...|129.99|   4|
# |ffeee66ac5d5a62fe...|129.99|   4|
# |ffeee66ac5d5a62fe...|129.99|   4|
# |ffeee66ac5d5a62fe...|129.99|   4|
# |ffeee66ac5d5a62fe...|129.99|   4|
# |ffeee66ac5d5a62fe...|129.99|   4|
# |
# |ff1e15b778c700abd...|  59.9|   1|
# |ff1e15b778c700abd...|  59.9|   1|
# |ff1e15b778c700abd...|  59.9|   1|
# |ff1e15b778c700abd...|  59.9|   1|
# |ff1e15b778c700abd...|  59.9|   1|
# |ff1e15b778c700abd...|  59.9|   1|
# |ff063b022a9a0aab9...|1230.0|   1|
# |ff063b022a9a0aab9...| 990.0|   2|
# |ff063b022a9a0aab9...| 990.0|   2|
# |ff063b022a9a0aab9...| 154.0|   4|
# |ff063b022a9a0aab9...| 154.0|   4|
# |ff063b022a9a0aab9...| 154.0|   4|
# |fedf2c1386e137f29...| 35.28|   1|
# |fedf2c1386e137f29...| 35.28|   1|
# |fedf2c1386e137f29...| 35.28|   1|
# |fedf2c1386e137f29...| 12.95|   4|
# |fedf2c1386e137f29...| 12.95|   4|
# +--------------------+------+----+
# only showing top 100 rows

# %%
#total revenue and avg order value

customer_sp=order_details.groupBy('customer_id').agg(\
                                                    count('order_id').alias('total_orders'),\
                                                    sum('price').alias('total_spent'),
                                                    round(avg('price'),2).alias('AOV')).orderBy(col('total_spent').desc())
customer_sp.show()
# Out:
# [Stage 309:============================>                            (1 + 1) / 2]
# +--------------------+------------+------------------+-------+
# |         customer_id|total_orders|       total_spent|    AOV|
# +--------------------+------------+------------------+-------+
# |1617b1357756262bf...|           8|           13440.0| 1680.0|
# |9af2372a1e4934027...|          29|11383.949999999997| 392.55|
# |de832e8dbb1f588a4...|          15|10856.099999999999| 723.74|
# |63b964e79dee32a35...|          24|            9888.0|  412.0|
# |6f241d5bbb142b6f7...|           7| 9520.140000000001|1360.02|
# |926b6a6fb8b6081e0...|           2|            7998.0| 3999.0|
# |f959b7bc834045511...|           6|            7799.4| 1299.9|
# |eb7a157e8da9c488c...|           2|            7798.0| 3899.0|
# |ec5b2ba62e5743423...|           4|            7160.0| 1790.0|
# |3118aefef04e5e97d...|           7|            6909.0|  987.0|
# |c6e2731c5b391845f...|           1|            6735.0| 6735.0|
# |f48d464a0baaea338...|           1|            6729.0| 6729.0|
# |3fd6777bbce08a352...|           1|            6499.0| 6499.0|
# |46bb3c0b1a65c8399...|           2|            6248.0| 3124.0|
# |d1ea705f2fdd8f98e...|          14| 6019.859999999998| 429.99|
# |05455dfa7cd02f13d...|           6|            5934.6|  989.1|
# |d3e82ccec3cb5f956...|           6|            5814.0|  969.0|
# |3690e975641f01bd0...|           2|            5298.0| 2649.0|
# |c47f0ed7fbd21fc9b...|           9| 4931.909999999999| 547.99|
# |a99b2128d3db96e83...|           8|            4800.0|  600.0|
# +--------------------+------------+------------------+-------+
# only showing top 20 rows

# %%
#seller performance metrics (revenue,average review,order count)

seller_sp=order_details.groupBy('seller_id').agg(\
                                                 count('order_id').alias('total_orders'),\
                                                 sum('price').alias('total_revenue'),\
                                                 round(avg('review_score'),2).alias('avg_review_score'),\
                                                 round(stddev('price'),2).alias('price variability'))\
                                                 .orderBy(col('total_revenue').desc())
                                                 
seller_sp.show()
# Out:
# [Stage 147:============================>                            (1 + 1) / 2]
# +--------------------+------------+--------------------+----------------+-----------------+
# |           seller_id|total_orders|       total_revenue|avg_review_score|price variability|
# +--------------------+------------+--------------------+----------------+-----------------+
# |4869f7a5dfa277a7d...|      184587| 3.613871731999314E7|            4.09|           111.65|
# |53243585a1d6dc264...|       54514|3.4291592950000696E7|            4.12|           499.65|
# |4a3ca9315b744ce9f...|      330661| 3.375957084001202E7|            3.77|            59.37|
# |7c67e1448b00f6e96...|      233306|3.2282321790021457E7|            3.42|            50.39|
# |fa1c13f2614d7b5c4...|       87686|3.0139386310006626E7|            4.38|            307.7|
# |da8622b14eb17ae28...|      264433| 2.985766973003611E7|            3.98|            72.92|
# |7e93a43ef30c4f03f...|       50226| 2.631570630000355E7|            4.15|           377.24|
# |1025f0e2d44d7041d...|      229587|2.2937518520012792E7|            3.89|             84.3|
# |46dc3b2cc0980fb8e...|       90426| 2.179177329001608E7|            4.18|           187.49|
# |955fee9216a65b617...|      232364|2.0964410670017645E7|            4.04|            84.94|
# |7a67c85e85bb2ce85...|      167231| 2.031279489002914E7|            4.26|            56.23|
# |620c87c171fb2a6dd...|      142232| 2.011983960002505E7|            4.36|           100.45|
# |7d13fca1522535862...|       88807|1.8156881910003982E7|            4.07|           151.18|
# |a1043bafd471dff53...|      132672|1.7662675980010696E7|            4.25|            37.19|
# |6560211a19b47992c...|      286539|1.7315932900000528E7|            3.86|            35.04|
# |edb1ef5e36e0c8cd8...|       38945|1.6624835150007125E7|            4.43|           460.85|
# |1f50f920176fa81da...|      297292|1.6497454440033637E7|            4.04|             7.39|
# |5dceca129747e92ff...|       50420|1.4910548340003535E7|            4.17|           299.84|
# |cc419e0650a3c5ba7...|      256032| 1.475146450003979E7|            4.07|            22.67|
# |3d871de0142ce09b7...|      175876|1.4184525300004762E7|            4.15|            38.14|
# +--------------------+------------+--------------------+----------------+-----------------+
# only showing top 20 rows

# %%
#product popularity matrix

product_metrics=order_details.groupBy('product_id').agg(\
                                                        count('order_id').alias('total_sales'),\
                                                        sum('price').alias('total_revenue'),\
                                                        round(avg('price'),2).alias('avg_price'),\
                                                        round(stddev('price'),2).alias('price_volatility'),\
                                                        collect_list('seller_id').alias('unique_sellers')).\
orderBy(col('total_sales').desc())
product_metrics.show()
# Out:
# +--------------------+-----------+------------------+---------+----------------+--------------------+
# |          product_id|total_sales|     total_revenue|avg_price|price_volatility|      unique_sellers|
# +--------------------+-----------+------------------+---------+----------------+--------------------+
# |aca2eb7d00ea1a7b8...|      86740| 6164630.299996104|    71.07|            3.17|[955fee9216a65b61...|
# |422879e10f4668299...|      81110| 4442791.509997985|    54.77|            4.46|[1f50f920176fa81d...|
# |99a4788cb24856965...|      78775| 6921762.709996391|    87.87|            4.08|[4a3ca9315b744ce9...|
# |389d119b48cf3043d...|      60248| 3280533.129998789|    54.45|            4.37|[1f50f920176fa81d...|
# |d1c427060a0f73f6b...|      59274| 8220103.330003063|   138.68|           16.58|[a1043bafd471dff5...|
# |368c6c730842d7801...|      58358|3181698.8999990216|    54.52|            4.59|[1f50f920176fa81d...|
# |53759a2ecddad2bb8...|      52654|2893017.4999995097|    54.94|            4.52|[1f50f920176fa81d...|
# |53b36df67ebb7c415...|      52105| 6159887.409998347|   118.22|           20.13|[7d13fca152253586...|
# |154e7e31ebfa09220...|      42700| 962160.9999997399|    22.53|            1.92|[cc419e0650a3c5ba...|
# |3dd2a17168ec895c7...|      40787| 6116941.299997734|   149.97|            0.85|[de722cd6dad950a9...|
# |e53e557d5a159f5aa...|      39516| 3329353.949999673|    84.25|           11.32|[0b90b6df587eb836...|
# |2b4609f8948be1887...|      36179|3171618.7699996904|    87.66|            4.22|[cc419e0650a3c5ba...|
# |35afc973633aaeb6b...|      31206|2735668.9999992615|    87.66|            3.32|[4a3ca9315b744ce9...|
# |e0d64dcfaa3b6db5c...|      31153| 5226407.629999433|   167.77|            30.9|[4869f7a5dfa277a7...|
# |42a2c92a0979a949c...|      30486|1810926.0000002957|     59.4|            0.64|[813348c996469b40...|
# |7c1bd920dbdf22470...|      29018| 1739338.819999779|    59.94|            2.77|[cc419e0650a3c5ba...|
# |a62e25e09e05e6faf...|      28898|         3079869.0|   106.58|             1.5|[634964b17796e643...|
# |5a848e4ab52fd5445...|      28737|3534363.6299997894|   122.99|             0.0|[c826c40d7b19f62a...|
# |c4baedd846ed09b85...|      28166|2802044.6499998383|    99.48|            11.9|[a1043bafd471dff5...|
# |b532349fe46b38fbc...|      27176| 993089.5700001396|    36.54|            1.92|[1025f0e2d44d7041...|
# +--------------------+-----------+------------------+---------+----------------+--------------------+
# only showing top 20 rows

# %%
#monthly revenue and order count trend

total orders
total revenue
avg order value 
min order value
max order value

# %%
#customer retention analysis -> first and last order

customer_re=order_details.groupBy('customer_id').agg(\
                                                     min('order_purchase_timestamp').alias('first_order_date'),\
                                                     max('order_purchase_timestamp').alias('last_order_date'),\
                                                     count('order_id').alias('total_orders_placed'),\
                                                     round(avg('price'),2).alias('avg_order_value')).\
orderBy(col('total_orders_placed').desc())
customer_re.show(truncate=False)
# Out:
# [Stage 207:============================>                            (1 + 1) / 2]
# +--------------------------------+-------------------+-------------------+-------------------+---------------+
# |customer_id                     |first_order_date   |last_order_date    |total_orders_placed|avg_order_value|
# +--------------------------------+-------------------+-------------------+-------------------+---------------+
# |351e40989da90e70487765f6ea15d54b|2017-07-13 10:42:37|2017-07-13 10:42:37|11427              |85.99          |
# |50920f8cd0681fd86ebe93670c8fe52e|2018-01-27 11:28:32|2018-01-27 11:28:32|10752              |43.82          |
# |9b43e2a62de9bab3ad220e858e95ccbc|2017-05-25 22:27:50|2017-05-25 22:27:50|8556               |26.4           |
# |270c23a11d024a44c896d1894b261a83|2017-08-08 20:26:31|2017-08-08 20:26:31|8001               |36.59          |
# |5c87184371002d49e08b9ac10eb96647|2018-01-05 19:15:37|2018-01-05 19:15:37|6876               |12.49          |
# |d3e82ccec3cb5f956a38d96c057ceaae|2017-03-18 14:28:34|2017-03-18 14:28:34|6876               |969.0          |
# |d5f2b3f597c7ccafbb5cac0bcc3d6024|2017-12-13 14:21:15|2017-12-13 14:21:15|6706               |59.0           |
# |c2f18647725395af4ad8cb9d34ff1287|2018-03-06 19:21:47|2018-03-06 19:21:47|6612               |34.9           |
# |24e7dc2ff8c07126358af519732b8558|2017-11-24 16:16:45|2017-11-24 16:16:45|6597               |59.2           |
# |7bb57d182bdc11653fac1593436df8bf|2018-04-02 17:11:30|2018-04-02 17:11:30|6258               |86.9           |
# |63b964e79dee32a3587651701a2b8dbf|2018-02-14 16:34:27|2018-02-14 16:34:27|6072               |412.0          |
# |d22f25a9fadfb1abbc2e29395b1239f4|2018-05-12 12:28:58|2018-05-12 12:28:58|6072               |14.99          |
# |1ff773612ab8934db89fd5afa8afe506|2018-04-19 13:54:06|2018-04-19 13:54:06|5820               |284.99         |
# |13aa59158da63ba0e93ec6ac2c07aacb|2017-09-23 14:56:45|2017-09-23 14:56:45|5206               |79.99          |
# |78fc46047c4a639e81ff65f0396e02fe|2017-11-28 22:24:18|2017-11-28 22:24:18|5200               |109.97         |
# |dd3f1762eb601f41c5e289fa08dbc6bf|2018-07-18 12:59:21|2018-07-18 12:59:21|4992               |179.99         |
# |a193aa8d905b8e2460a1f49e26caa4a9|2018-02-12 18:04:28|2018-02-12 18:04:28|4896               |9.99           |
# |9eb3d566e87289dcb0acf28e1407c839|2018-06-08 16:42:11|2018-06-08 16:42:11|4872               |5.11           |
# |2ba91e12e5e4c9f56b82b86d9031d329|2017-11-25 13:54:39|2017-11-25 13:54:39|4752               |99.9           |
# |55e7cfd6e28d2fbfbf01477c1d6171e2|2017-06-25 17:50:06|2017-06-25 17:50:06|4728               |36.9           |
# +--------------------------------+-------------------+-------------------+-------------------+---------------+
# only showing top 20 rows

# %%
orders_df.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- order_status: string (nullable = true)
#  |-- order_purchase_timestamp: timestamp (nullable = true)
#  |-- order_approved_at: timestamp (nullable = true)
#  |-- order_delivered_carrier_date: timestamp (nullable = true)
#  |-- order_delivered_customer_date: timestamp (nullable = true)
#  |-- order_estimated_delivery_date: timestamp (nullable = true)

# %%
order_details.filter(col('customer_id') == 'f1e46939e6408b3e6fd46579a37c88b4').select('order_purchase_timestamp').show()
# Out:
# +------------------------+
# |order_purchase_timestamp|
# +------------------------+
# |     2017-06-01 14:58:11|
# |     2017-06-01 14:58:11|
# |     2017-06-01 14:58:11|
# |     2017-06-01 14:58:11|
# |     2017-06-01 14:58:11|
# |     2017-06-01 14:58:11|
# |     2017-06-01 14:58:11|
# |     2017-06-01 14:58:11|
# |     2017-06-01 14:58:11|
# |     2017-06-01 14:58:11|
# |     2017-06-01 14:58:11|
# |     2017-06-01 14:58:11|
# |     2017-06-01 14:58:11|
# |     2017-06-01 14:58:11|
# |     2017-06-01 14:58:11|
# |     2017-06-01 14:58:11|
# |     2017-06-01 14:58:11|
# |     2017-06-01 14:58:11|
# |     2017-06-01 14:58:11|
# |     2017-06-01 14:58:11|
# +------------------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import col

# assuming customer_re has first_order_date and last_order_date columns
customer_re.filter(col('first_order_date') != col('last_order_date')).show()
# Out:
# [Stage 259:============================>                            (1 + 1) / 2]
# +-----------+----------------+---------------+-------------------+---------------+
# |customer_id|first_order_date|last_order_date|total_orders_placed|avg_order_value|
# +-----------+----------------+---------------+-------------------+---------------+
# +-----------+----------------+---------------+-------------------+---------------+

# %%
orders_df.groupBy('customer_id').count().orderBy(col('count').desc()).show()
# Out:
# +--------------------+-----+
# |         customer_id|count|
# +--------------------+-----+
# |f1e46939e6408b3e6...|    1|
# |3391c4bc11a817e79...|    1|
# |90d7075599361b694...|    1|
# |5a58afc695ee03b9b...|    1|
# |a340ce6c3570e68d4...|    1|
# |9687241c8ed401845...|    1|
# |b76530b7e66b27cd6...|    1|
# |a3537e15f3e4f88e0...|    1|
# |4d91a0aeb419c5f26...|    1|
# |2774b6023c768c91e...|    1|
# |2aec499f94f5e8278...|    1|
# |5a6ae5b68fd27c687...|    1|
# |791fffae1e2c66693...|    1|
# |2b139a6842a26c357...|    1|
# |0721e1c4b91bc6ded...|    1|
# |9601347c41eb3f6dd...|    1|
# |d480546bdc6b03fca...|    1|
# |be170bc588de8c9e1...|    1|
# |6f8b4eeaba59ef3fa...|    1|
# |18dff7c2afb1ce5fb...|    1|
# +--------------------+-----+
# only showing top 20 rows

# %%
customer_df.count()
# Out:
# 99441

# %%
orders_df.count()
# Out:
# 99441

# %%
orders_df.join(customer_df,'customer_id','inner').count()
# Out:
# 99441

# %%
geolocation_df.filter(col('geolocation_zip_code_prefix')=='2122').show()
# Out:
# +---------------------------+-------------------+-------------------+----------------+-----------------+
# |geolocation_zip_code_prefix|    geolocation_lat|    geolocation_lng|geolocation_city|geolocation_state|
# +---------------------------+-------------------+-------------------+----------------+-----------------+
# |                       2122|-23.513172191788303| -46.58263962184772|       sao paulo|               SP|
# |                       2122|-23.512200548156255| -46.58175211601936|       sao paulo|               SP|
# |                       2122|-23.511529487650744| -46.58759916694558|       sao paulo|               SP|
# |                       2122|-23.512050000000002|-46.584090539961934|       sao paulo|               SP|
# |                       2122|-23.513043970309834|-46.584710465173956|       são paulo|               SP|
# |                       2122|-23.511865861503836| -46.58364351012754|       sao paulo|               SP|
# |                       2122|         -23.512572| -46.58519024999999|       são paulo|               SP|
# |                       2122|-23.512753719112535|-46.581821276992315|       sao paulo|               SP|
# |                       2122|-23.511119008050084|-46.588612986958246|       são paulo|               SP|
# |                       2122| -23.51234166694557| -46.58356862836862|       sao paulo|               SP|
# |                       2122| -23.51139805023373| -46.58326616985977|       são paulo|               SP|
# |                       2122|-23.511865861503836| -46.58364351012754|       sao paulo|               SP|
# |                       2122|-23.509501490709166|-46.590371397310854|       sao paulo|               SP|
# |                       2122|-23.512200548156255| -46.58175211601936|       sao paulo|               SP|
# |                       2122|-23.512150822959867|-46.581799015724826|       sao paulo|               SP|
# |                       2122| -23.51145242714524| -46.58783617929481|       são paulo|               SP|
# |                       2122|-23.512200548156255| -46.58175211601936|       sao paulo|               SP|
# |                       2122|-23.512200548156255| -46.58175211601936|       sao paulo|               SP|
# |                       2122| -23.51139805023373| -46.58326616985977|       sao paulo|               SP|
# |                       2122|-23.512200548156255| -46.58175211601936|       sao paulo|               SP|
# +---------------------------+-------------------+-------------------+----------------+-----------------+
# only showing top 20 rows

# %%
geolocation_df.count()
# Out:
# 19015

# %%
order_details.groupBy('customer_id').count().orderBy(col('count').desc()).show()
# Out:
# [Stage 333:============================>                            (1 + 1) / 2]
# +--------------------+-----+
# |         customer_id|count|
# +--------------------+-----+
# |270c23a11d024a44c...|   63|
# |13aa59158da63ba0e...|   38|
# |9af2372a1e4934027...|   29|
# |92cd3ec6e2d643d4e...|   26|
# |2ba91e12e5e4c9f56...|   24|
# |63b964e79dee32a35...|   24|
# |6ee2f17e3b6c33d6a...|   24|
# |86cc80fef09f7f39d...|   24|
# |d22f25a9fadfb1abb...|   24|
# |be1c4e52bb71e0c54...|   22|
# |b246eeed30b362c09...|   22|
# |fc3d1daec319d62d4...|   21|
# |5e0f7317756669ff7...|   21|
# |50920f8cd0681fd86...|   21|
# |23924b2105c5376cd...|   20|
# |be1b70680b9f9694d...|   20|
# |bd5d39761aa56689a...|   20|
# |eed931d3a5222a9a5...|   19|
# |1d48a5dcde374b9d6...|   16|
# |1d4411212e90d6a24...|   16|
# +--------------------+-----+
# only showing top 20 rows

# %%
order_items_df.groupBy('order_id').count().orderBy(col('count').desc()).show(truncate=False)
# Out:
# +--------------------------------+-----+
# |order_id                        |count|
# +--------------------------------+-----+
# |8272b63d03f5f79c56e9e4120aec44ef|21   |
# |1b15974a0141d54e36626dca3fdc731a|20   |
# |ab14fdcfbe524636d65ee38360e22ce8|20   |
# |9ef13efd6949e4573a18964dd1bbe7f5|15   |
# |428a2f660dc84138d969ccd69a0ab6d5|15   |
# |9bdc4d4c71aa1de4606060929dee888c|14   |
# |73c8ab38f07dc94389065f7eba4f297a|14   |
# |37ee401157a3a0b28c9c6d0ed8c3b24b|13   |
# |af822dacd6f5cff7376413c03a388bb7|12   |
# |2c2a19b5703863c908512d135aa6accc|12   |
# |3a213fcdfe7d98be74ea0dc05a8b31ae|12   |
# |c05d6a79e55da72ca780ce90364abed9|12   |
# |637617b3ffe9e2f7a2411243829226d0|12   |
# |71dab1155600756af6de79de92e712e3|11   |
# |5a3b1c29a49756e75f1ef513383c0c12|11   |
# |7f2c22c54cbae55091a09a9653fd2b8a|11   |
# |6c355e2913545fa6f72c40cbca57729e|11   |
# |9aec4e1ae90b23c7bf2d2b3bfafbd943|10   |
# |9f5054bd9a3c71702aa0917a7da29193|10   |
# |30bdf3d824d824610a49887486debcaf|10   |
# +--------------------------------+-----+
# only showing top 20 rows

# %%
order_items_df.filter(col('order_id')=='8272b63d03f5f79c56e9e4120aec44ef').show()
# Out:
# +--------------------+-------------+--------------------+--------------------+-------------------+-----+-------------+
# |            order_id|order_item_id|          product_id|           seller_id|shipping_limit_date|price|freight_value|
# +--------------------+-------------+--------------------+--------------------+-------------------+-----+-------------+
# |8272b63d03f5f79c5...|            1|270516a3f41dc035a...|2709af9587499e95e...|2017-07-21 18:25:23|  1.2|         7.89|
# |8272b63d03f5f79c5...|            2|05b515fdc76e888aa...|2709af9587499e95e...|2017-07-21 18:25:23|  1.2|         7.89|
# |8272b63d03f5f79c5...|            3|05b515fdc76e888aa...|2709af9587499e95e...|2017-07-21 18:25:23|  1.2|         7.89|
# |8272b63d03f5f79c5...|            4|05b515fdc76e888aa...|2709af9587499e95e...|2017-07-21 18:25:23|  1.2|         7.89|
# |8272b63d03f5f79c5...|            5|05b515fdc76e888aa...|2709af9587499e95e...|2017-07-21 18:25:23|  1.2|         7.89|
# |8272b63d03f5f79c5...|            6|05b515fdc76e888aa...|2709af9587499e95e...|2017-07-21 18:25:23|  1.2|         7.89|
# |8272b63d03f5f79c5...|            7|05b515fdc76e888aa...|2709af9587499e95e...|2017-07-21 18:25:23|  1.2|         7.89|
# |8272b63d03f5f79c5...|            8|05b515fdc76e888aa...|2709af9587499e95e...|2017-07-21 18:25:23|  1.2|         7.89|
# |8272b63d03f5f79c5...|            9|05b515fdc76e888aa...|2709af9587499e95e...|2017-07-21 18:25:23|  1.2|         7.89|
# |8272b63d03f5f79c5...|           10|05b515fdc76e888aa...|2709af9587499e95e...|2017-07-21 18:25:23|  1.2|         7.89|
# |8272b63d03f5f79c5...|           11|05b515fdc76e888aa...|2709af9587499e95e...|2017-07-21 18:25:23|  1.2|         7.89|
# |8272b63d03f5f79c5...|           12|270516a3f41dc035a...|2709af9587499e95e...|2017-07-21 18:25:23|  1.2|         7.89|
# |8272b63d03f5f79c5...|           13|270516a3f41dc035a...|2709af9587499e95e...|2017-07-21 18:25:23|  1.2|         7.89|
# |8272b63d03f5f79c5...|           14|270516a3f41dc035a...|2709af9587499e95e...|2017-07-21 18:25:23|  1.2|         7.89|
# |8272b63d03f5f79c5...|           15|270516a3f41dc035a...|2709af9587499e95e...|2017-07-21 18:25:23|  1.2|         7.89|
# |8272b63d03f5f79c5...|           16|270516a3f41dc035a...|2709af9587499e95e...|2017-07-21 18:25:23|  1.2|         7.89|
# |8272b63d03f5f79c5...|           17|270516a3f41dc035a...|2709af9587499e95e...|2017-07-21 18:25:23|  1.2|         7.89|
# |8272b63d03f5f79c5...|           18|270516a3f41dc035a...|2709af9587499e95e...|2017-07-21 18:25:23|  1.2|         7.89|
# |8272b63d03f5f79c5...|           19|270516a3f41dc035a...|2709af9587499e95e...|2017-07-21 18:25:23|  1.2|         7.89|
# |8272b63d03f5f79c5...|           20|270516a3f41dc035a...|2709af9587499e95e...|2017-07-21 18:25:23|  1.2|         7.89|
# +--------------------+-------------+--------------------+--------------------+-------------------+-----+-------------+
# only showing top 20 rows

# %%
# Out:
# +--------------------+--------------------+------------------+-------------------+
# |            order_id|           seller_id|       total_price|total_freight_value|
# +--------------------+--------------------+------------------+-------------------+
# |000229ec398224ef6...|5b51032eddd242adc...|             199.0|              17.87|
# |00054e8431b9d7675...|7040e82f899a04d1b...|              19.9|              11.85|
# |000576fe39319847c...|5996cddab893a4652...|             810.0|              70.75|
# |0005a1a1728c9d785...|a416b6a846a117243...|            145.95|              11.65|
# |0005f50442cb953dc...|ba143b05f0110f0dc...|             53.99|               11.4|
# |00061f2a7bc09da83...|cc419e0650a3c5ba7...|             59.99|               8.88|
# |0006ec9db01a64e59...|4a3ca9315b744ce9f...|              74.0|              23.32|
# |0009792311464db53...|530ec6109d11eaaf8...|              99.9|              27.65|
# |0009c9a17f916a706...|fcb5ace8bcc92f757...|             639.0|              11.34|
# |000aed2e25dbad2f9...|fe2032dab1a61af87...|             144.0|               8.77|
# |000c3e6612759851c...|218d46b86c1881d02...|              99.0|              13.71|
# |000e562887b1f2006...|8cbac7e12637ed9cf...|              25.0|              16.11|
# |000e906b789b55f64...|ea8482cd71df3c196...|             21.99|              11.85|
# |000f25f4d72195062...|7c67e1448b00f6e96...|            119.99|               44.4|
# |0010b2e5201cc5f1a...|3504c0cb71d7fa48d...|              48.9|               16.6|
# |00119ff934e539cf2...|c864036feaab8c165...|             219.9|              16.98|
# |0011d82c4b53e22e8...|bfd27a966d91cfaaf...|             289.0|              26.33|
# |00130c0eee84a3d90...|16090f2ca825584b5...|              27.9|               7.94|
# |001427c0ec99cf8af...|77530e9772f57a62c...|              59.9|              23.35|
# |00143d0f86d6fbd9f...|a17f621c590ea0fab...|63.989999999999995|               45.3|
# +--------------------+--------------------+------------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# **extended enrichment**

# %%
order_details.select('order_status').show()
# Out:
# +------------+
# |order_status|
# +------------+
# |   delivered|
# |   delivered|
# |   delivered|
# |   delivered|
# |   delivered|
# |   delivered|
# |   delivered|
# |   delivered|
# |   delivered|
# |   delivered|
# |   delivered|
# |   delivered|
# |   delivered|
# |   delivered|
# |   delivered|
# |   delivered|
# |   delivered|
# |   delivered|
# |   delivered|
# |   delivered|
# +------------+
# only showing top 20 rows

# %%
order_details=order_details.withColumn('is_delivered',when(col('order_status')=='delivered',lit(1)).otherwise(lit(0)))\
                                       .withColumn('is_cancelled',when(col('order_status')=='canceled',lit(1)).otherwise(lit(0)))

# %%
order_details.filter(col('order_status')=='canceled').select('order_status','is_delivered','is_cancelled').show()
# Out:
# +------------+------------+------------+
# |order_status|is_delivered|is_cancelled|
# +------------+------------+------------+
# |    canceled|           0|           1|
# |    canceled|           0|           1|
# |    canceled|           0|           1|
# |    canceled|           0|           1|
# |    canceled|           0|           1|
# |    canceled|           0|           1|
# |    canceled|           0|           1|
# |    canceled|           0|           1|
# |    canceled|           0|           1|
# |    canceled|           0|           1|
# |    canceled|           0|           1|
# |    canceled|           0|           1|
# |    canceled|           0|           1|
# |    canceled|           0|           1|
# |    canceled|           0|           1|
# |    canceled|           0|           1|
# |    canceled|           0|           1|
# |    canceled|           0|           1|
# |    canceled|           0|           1|
# |    canceled|           0|           1|
# +------------+------------+------------+
# only showing top 20 rows

# %%
order_details.printSchema()
# Out:
# root
#  |-- order_id: string (nullable = true)
#  |-- seller_id: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- customer_id: string (nullable = true)
#  |-- order_status: string (nullable = true)
#  |-- order_purchase_timestamp: timestamp (nullable = true)
#  |-- order_approved_at: timestamp (nullable = true)
#  |-- order_delivered_carrier_date: timestamp (nullable = true)
#  |-- order_delivered_customer_date: timestamp (nullable = true)
#  |-- order_estimated_delivery_date: timestamp (nullable = true)
#  |-- total_price: double (nullable = true)
#  |-- total_freight_value: double (nullable = true)
#  |-- total_value: double (nullable = true)
#  |-- customer_unique_id: string (nullable = true)
#  |-- customer_zip_code_prefix: integer (nullable = true)
#  |-- customer_city: string (nullable = true)
#  |-- customer_state: string (nullable = true)
#  |-- product_category_name: string (nullable = true)
#  |-- product_name_lenght: integer (nullable = true)
#  |-- product_description_lenght: integer (nullable = true)
#  |-- product_photos_qty: integer (nullable = true)
#  |-- product_weight_g: integer (nullable = true)
#  |-- product_length_cm: integer (nullable = true)
#  |-- product_height_cm: integer (nullable = true)
#  |-- product_width_cm: integer (nullable = true)
#  |-- seller_zip_code_prefix: integer (nullable = true)
#  |-- seller_city: string (nullable = true)
#  |-- seller_state: string (nullable = true)
#  |-- geolocation_zip_code_prefix: integer (nullable = true)
#  |-- geolocation_lat: double (nullable = true)
#  |-- geolocation_lng: double (nullable = true)
#  |-- geolocation_city: string (nullable = true)
#  |-- geolocation_state: string (nullable = true)
#  |-- review_id: string (nullable = true)
#  |-- review_score: string (nullable = true)
#  |-- review_comment_title: string (nullable = true)
#  |-- review_comment_message: string (nullable = true)
#  |-- review_creation_date: string (nullable = true)
#  |-- review_answer_timestamp: string (nullable = true)
#  |-- is_delivered: integer (nullable = false)
#  |-- is_cancelled: integer (nullable = false)

# %%
#customer segmentation based on spending

customer_spending=order_details.groupBy('customer_id').agg(sum(col('total_value')).alias('total_spending')).orderBy(col('total_spending').desc())
customer_spending.show()
# Out:
# [Stage 231:============================>                            (1 + 1) / 2]
# +--------------------+--------------+
# |         customer_id|total_spending|
# +--------------------+--------------+
# |1617b1357756262bf...|      13664.08|
# |ec5b2ba62e5743423...|       7274.88|
# |c6e2731c5b391845f...|       6929.31|
# |f48d464a0baaea338...|       6922.21|
# |3fd6777bbce08a352...|       6726.66|
# |05455dfa7cd02f13d...|       6081.54|
# |df55c14d1476a9a34...|       4950.34|
# |e0a2412720e9ea4f2...|       4809.44|
# |24bbf5fd2f2e1b359...|       4764.34|
# |3d979689f636322c6...|       4681.78|
# |1afc82cd60e303ef0...|       4513.32|
# |cc803a2c412833101...|        4445.5|
# |926b6a6fb8b6081e0...|       4194.76|
# |35a413c7ca3c69756...|       4175.26|
# |e9b0d0eb3015ef1c9...|       4163.51|
# |3be2c536886b2ea46...|       4042.74|
# |eb7a157e8da9c488c...|       4034.44|
# |c6695e3b1e48680db...|       4016.91|
# |31e83c01fce824d0f...|       3979.55|
# |addc91fdf9c2b3045...|        3826.8|
# +--------------------+--------------+
# only showing top 20 rows

# %%
customer_spending=customer_spending.withColumn('segment',when(col('total_spending')>=1200,'High value').when((col('total_spending')>=500) & (col('total_spending')<1200),'medium value').otherwise('low value'))
customer_spending.show()
# Out:
# [Stage 241:>                                                        (0 + 2) / 2]
# +--------------------+--------------+----------+
# |         customer_id|total_spending|   segment|
# +--------------------+--------------+----------+
# |1617b1357756262bf...|      13664.08|High value|
# |ec5b2ba62e5743423...|       7274.88|High value|
# |c6e2731c5b391845f...|       6929.31|High value|
# |f48d464a0baaea338...|       6922.21|High value|
# |3fd6777bbce08a352...|       6726.66|High value|
# |05455dfa7cd02f13d...|       6081.54|High value|
# |df55c14d1476a9a34...|       4950.34|High value|
# |e0a2412720e9ea4f2...|       4809.44|High value|
# |24bbf5fd2f2e1b359...|       4764.34|High value|
# |3d979689f636322c6...|       4681.78|High value|
# |1afc82cd60e303ef0...|       4513.32|High value|
# |cc803a2c412833101...|        4445.5|High value|
# |926b6a6fb8b6081e0...|       4194.76|High value|
# |35a413c7ca3c69756...|       4175.26|High value|
# |e9b0d0eb3015ef1c9...|       4163.51|High value|
# |3be2c536886b2ea46...|       4042.74|High value|
# |eb7a157e8da9c488c...|       4034.44|High value|
# |c6695e3b1e48680db...|       4016.91|High value|
# |31e83c01fce824d0f...|       3979.55|High value|
# |addc91fdf9c2b3045...|        3826.8|High value|
# +--------------------+--------------+----------+
# only showing top 20 rows

# %%
order_details=order_details.join(customer_spending,'customer_id','left')
order_details.show()
# Out:
# 25/11/14 09:55:56 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +--------------------+--------------------+--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+-----------+-------------------+-----------+--------------------+------------------------+--------------------+--------------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+----------------------+--------------------+------------+---------------------------+-------------------+-------------------+--------------------+-----------------+--------------------+------------+--------------------+----------------------+--------------------+-----------------------+------------+------------+--------------+---------+
# |         customer_id|            order_id|           seller_id|          product_id|order_status|order_purchase_timestamp|  order_approved_at|order_delivered_carrier_date|order_delivered_customer_date|order_estimated_delivery_date|total_price|total_freight_value|total_value|  customer_unique_id|customer_zip_code_prefix|       customer_city|customer_state|product_category_name|product_name_lenght|product_description_lenght|product_photos_qty|product_weight_g|product_length_cm|product_height_cm|product_width_cm|seller_zip_code_prefix|         seller_city|seller_state|geolocation_zip_code_prefix|    geolocation_lat|    geolocation_lng|    geolocation_city|geolocation_state|           review_id|review_score|review_comment_title|review_comment_message|review_creation_date|review_answer_timestamp|is_delivered|is_cancelled|total_spending|  segment|
# +--------------------+--------------------+--------------------+--------------------+------------+------------------------+-------------------+----------------------------+-----------------------------+-----------------------------+-----------+-------------------+-----------+--------------------+------------------------+--------------------+--------------+---------------------+-------------------+--------------------------+------------------+----------------+-----------------+-----------------+----------------+----------------------+--------------------+------------+---------------------------+-------------------+-------------------+--------------------+-----------------+--------------------+------------+--------------------+----------------------+--------------------+-----------------------+------------+------------+--------------+---------+
# |f7277fce45fad3165...|0013503b13da1eac6...|1554a68530182680a...|38afdf723b95d455b...|   delivered|     2017-12-05 23:40:59|2017-12-07 03:16:36|         2017-12-07 22:59:30|          2017-12-20 22:46:28|          2017-12-28 00:00:00|      119.9|              17.32|     137.22|1544f85dff3797491...|                    6160|              osasco|            SP|     moveis_decoracao|                 38|                       479|                 3|            2500|               34|                6|              28|                 37580|          monte siao|          MG|                       6160| -23.56267680949066|-46.809370406703835|              osasco|               SP|b5c9aa83935388c89...|           5|                NULL|                  NULL| 2017-12-21 00:00:00|    2017-12-24 05:03:01|           1|           0|        137.22|low value|
# |98884e672c5ba85f4...|000e63d38ae8c00bb...|1c129092bf23f28a5...|553e0e7590d3116a0...|   delivered|     2018-03-23 19:48:26|2018-03-23 20:07:49|         2018-03-26 21:38:48|          2018-03-27 14:51:47|          2018-04-05 00:00:00|       47.9|               8.88|      56.78|860fc00d3154ce234...|                    4679|           sao paulo|            SP|      cama_mesa_banho|                 38|                       735|                 5|             800|               20|               20|              20|                  2972|           sao paulo|          SP|                       4679| -23.67501017124474|-46.679538766172286|           sao paulo|               SP|06f45fcd8b9b54c30...|           3|                NULL|                     5| 2018-03-28 00:00:00|    2018-03-28 18:32:10|           1|           0|         56.78|low value|
------+-----------------+--------------------+------------+--------------------+----------------------+--------------------+-----------------------+------------+------------+--------------+---------+
# only showing top 20 rows

# %%
#hourly order distribution

order_details=order_details.withColumn('hour_of_day',hour(col('order_purchase_timestamp')))
order_details.count()
# Out:
# 98666

# %%
order_details.select('hour_of_day').show()
# Out:
# +-----------+
# |hour_of_day|
# +-----------+
# |         14|
# |         11|
# |         12|
# |         18|
# |         13|
# |         22|
# |         17|
# |         20|
# |          9|
# |         20|
# |         10|
# |         11|
# |         18|
# |         10|
# |         17|
# |          0|
# |         21|
# |         21|
# |         18|
# |         15|
# +-----------+
# only showing top 20 rows

# %%
order_details=order_details.withColumn('isWeekend',when(dayofweek(col('order_purchase_timestamp'))==1,1).when(dayofweek(col('order_purchase_timestamp'))==7,1).otherwise(0))

# %%
order_details.select('isWeekend','order_purchase_timestamp').show()
# Out:
# +---------+------------------------+
# |isWeekend|order_purchase_timestamp|
# +---------+------------------------+
# |        1|     2018-01-14 14:33:31|
# |        1|     2017-12-10 11:53:48|
# |        0|     2018-07-04 12:08:27|
# |        0|     2018-03-19 18:40:33|
# |        0|     2018-07-02 13:59:39|
# |        1|     2018-03-24 22:16:10|
# |        0|     2018-07-24 17:04:17|
# |        0|     2018-08-14 20:43:09|
# |        0|     2018-04-25 09:10:41|
# |        0|     2018-05-11 20:33:38|
# |        1|     2017-08-12 10:08:57|
# |        0|     2018-02-22 11:54:42|
# |        0|     2017-11-21 18:54:23|
# |        0|     2018-03-07 10:33:13|
# |        0|     2017-09-11 17:39:33|
# |        1|     2017-08-06 00:42:49|
# |        0|     2018-01-16 21:43:23|
# |        0|     2018-06-11 21:17:00|
# |        1|     2018-04-07 18:51:22|
# |        0|     2017-10-16 15:29:43|
# +---------+------------------------+
# only showing top 20 rows

# %%
order_details.printSchema()
# Out:
# root
#  |-- customer_id: string (nullable = true)
#  |-- order_id: string (nullable = true)
#  |-- seller_id: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- order_status: string (nullable = true)
#  |-- order_purchase_timestamp: timestamp (nullable = true)
#  |-- order_approved_at: timestamp (nullable = true)
#  |-- order_delivered_carrier_date: timestamp (nullable = true)
#  |-- order_delivered_customer_date: timestamp (nullable = true)
#  |-- order_estimated_delivery_date: timestamp (nullable = true)
#  |-- total_price: double (nullable = true)
#  |-- total_freight_value: double (nullable = true)
#  |-- total_value: double (nullable = true)
#  |-- customer_unique_id: string (nullable = true)
#  |-- customer_zip_code_prefix: integer (nullable = true)
#  |-- customer_city: string (nullable = true)
#  |-- customer_state: string (nullable = true)
#  |-- product_category_name: string (nullable = true)
#  |-- product_name_lenght: integer (nullable = true)
#  |-- product_description_lenght: integer (nullable = true)
#  |-- product_photos_qty: integer (nullable = true)
#  |-- product_weight_g: integer (nullable = true)
#  |-- product_length_cm: integer (nullable = true)
#  |-- product_height_cm: integer (nullable = true)
#  |-- product_width_cm: integer (nullable = true)
#  |-- seller_zip_code_prefix: integer (nullable = true)
#  |-- seller_city: string (nullable = true)
#  |-- seller_state: string (nullable = true)
#  |-- geolocation_zip_code_prefix: integer (nullable = true)
#  |-- geolocation_lat: double (nullable = true)
#  |-- geolocation_lng: double (nullable = true)
#  |-- geolocation_city: string (nullable = true)
#  |-- geolocation_state: string (nullable = true)
#  |-- review_id: string (nullable = true)
#  |-- review_score: string (nullable = true)
#  |-- review_comment_title: string (nullable = true)
#  |-- review_comment_message: string (nullable = true)
#  |-- review_creation_date: string (nullable = true)
#  |-- review_answer_timestamp: string (nullable = true)
#  |-- is_delivered: integer (nullable = false)
#  |-- is_cancelled: integer (nullable = false)
#  |-- total_spending: double (nullable = true)
#  |-- segment: string (nullable = true)
#  |-- hour_of_day: integer (nullable = true)
#  |-- isWeekend: integer (nullable = false)

# %%
#freight category


order_details=order_details.withColumn('freight_category',when(col('total_freight_value')>=30,'high_value').when((col('total_freight_value')>=20) & (col('total_freight_value')<30),'medium_value').otherwise('low_value'))
order_details.select('total_freight_value','freight_category').show()
# Out:
# +-------------------+----------------+
# |total_freight_value|freight_category|
# +-------------------+----------------+
# |              17.87|       low_value|
# |              11.85|       low_value|
# |              70.75|      high_value|
# |              11.65|       low_value|
# |               11.4|       low_value|
# |               8.88|       low_value|
# |              23.32|    medium_value|
# |              27.65|    medium_value|
# |              11.34|       low_value|
# |               8.77|       low_value|
# |              13.71|       low_value|
# |              16.11|       low_value|
# |              11.85|       low_value|
# |               44.4|      high_value|
# |               16.6|       low_value|
# |              16.98|       low_value|
# |              26.33|    medium_value|
# |               7.94|       low_value|
# |              23.35|    medium_value|
# |               45.3|      high_value|
# +-------------------+----------------+
# only showing top 20 rows

# %%
orders_by_state=order_details.groupBy(col('customer_state')).count().orderBy(col('count').desc())
orders_by_state.show()
# Out:
# +--------------+-----+
# |customer_state|count|
# +--------------+-----+
# |            SP|41375|
# |            RJ|12762|
# |            MG|11544|
# |            RS| 5432|
# |            PR| 4998|
# |            SC| 3612|
# |            BA| 3358|
# |            DF| 2125|
# |            ES| 2025|
# |            GO| 2007|
# |            PE| 1648|
# |            CE| 1327|
# |            PA|  970|
# |            MT|  903|
# |            MA|  740|
# |            MS|  709|
# |            PB|  532|
# |            PI|  493|
# |            RN|  482|
# |            AL|  411|
# +--------------+-----+
# only showing top 20 rows

# %%
order_details.write.mode('overwrite').parquet('/data/project/archive/final_data_processed.parquet')

# %%
# !hdfs dfs -ls /data/project/archive/
# Out:
# Found 10 items
# drwxr-xr-x   - root hadoop          0 2025-11-14 10:34 /data/project/archive/final_data_processed.parquet
# -rw-r--r--   2 pc   hadoop    9033957 2025-11-11 16:28 /data/project/archive/olist_customers_dataset.csv
# -rw-r--r--   2 pc   hadoop   61273883 2025-11-11 16:28 /data/project/archive/olist_geolocation_dataset.csv
# -rw-r--r--   2 pc   hadoop   15438671 2025-11-11 16:28 /data/project/archive/olist_order_items_dataset.csv
# -rw-r--r--   2 pc   hadoop    5777138 2025-11-11 16:28 /data/project/archive/olist_order_payments_dataset.csv
# -rw-r--r--   2 pc   hadoop   14451670 2025-11-11 16:28 /data/project/archive/olist_order_reviews_dataset.csv
# -rw-r--r--   2 pc   hadoop   17654914 2025-11-11 16:28 /data/project/archive/olist_orders_dataset.csv
# -rw-r--r--   2 pc   hadoop    2379446 2025-11-11 16:28 /data/project/archive/olist_products_dataset.csv
# -rw-r--r--   2 pc   hadoop     174703 2025-11-11 16:28 /data/project/archive/olist_sellers_dataset.csv
# -rw-r--r--   2 pc   hadoop       2613 2025-11-11 16:28 /data/project/archive/product_category_name_translation.csv

# %%
# !hdfs dfs -ls /data/project/archive/final_data_processed.parquet
# Out:
# Found 3 items
# -rw-r--r--   2 root hadoop          0 2025-11-14 10:34 /data/project/archive/final_data_processed.parquet/_SUCCESS
# -rw-r--r--   2 root hadoop   13083238 2025-11-14 10:34 /data/project/archive/final_data_processed.parquet/part-00000-032c4a00-8803-492e-a972-ed25dcaa820b-c000.snappy.parquet
# -rw-r--r--   2 root hadoop   13102203 2025-11-14 10:34 /data/project/archive/final_data_processed.parquet/part-00001-032c4a00-8803-492e-a972-ed25dcaa820b-c000.snappy.parquet

# %%
# !hdfs dfs -mkdir /data/processed

# %%
order_details.write.mode('overwrite').parquet('/data/processed/final_data_processed.parquet')

# %%
order_details.write.mode('overwrite').saveAsTable('full_order_detail')
# Out:
# ivysettings.xml file not found in HIVE_HOME or HIVE_CONF_DIR,/etc/hive/conf.dist/ivysettings.xml will be used
# 25/11/14 11:04:28 WARN SessionState: METASTORE_FILTER_HOOK will be ignored, since hive.security.authorization.manager is set to instance of HiveAuthorizerFactory.

# %%
spark.sql('show tables').show()
# Out:
# +---------+-----------------+-----------+
# |namespace|        tableName|isTemporary|
# +---------+-----------------+-----------+
# |  default|     customers300|      false|
# |  default|  customers_table|      false|
# |  default|full_order_detail|      false|
# |  default|    order_details|      false|
# +---------+-----------------+-----------+
